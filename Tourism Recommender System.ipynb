# %% [markdown]
# # Tourism Recommender System

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set Style for Better Plots
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("Set2")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# Load the dataset 
df = pd.read_csv('tourism_recommendation_dataset_en.csv')

# %% [markdown]
# ## Overview of Dataset

# %%
# Display Basic Info for Dataset
print("Dataset shape: {df.shape}")
print("Number of records: {df.shape[0]}")
print("Number of features: {df.shape[1]}")
print("\nColumn names:")
print(df.columns.tolist())
# Out:
# Dataset shape: {df.shape}
# Number of records: {df.shape[0]}
# Number of features: {df.shape[1]}
#
# Column names:
# ['tourist_id', 'gender', 'age', 'age_group', 'source_province', 'attraction_name', 'attraction_category', 'attraction_level', 'city', 'province', 'ticket_price', 'visit_date', 'visit_duration_hours', 'spend_amount', 'other_spend', 'rating', 'is_group_tour', 'group_fee', 'trip_days', 'main_spots', 'transport_mode', 'season', 'is_holiday', 'recommendation_level', 'satisfaction_level']

# %%
# Show Each Column Info
print("\nColumn Info:")
print(df.info())
# Out:
# Column Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   tourist_id            100000 non-null  int64
#  1   gender                100000 non-null  object
#  2   age                   100000 non-null  int64
#  3   age_group             100000 non-null  object
#  4   source_province       100000 non-null  object
#  5   attraction_name       100000 non-null  object
#  6   attraction_category   100000 non-null  object
#  7   attraction_level      100000 non-null  object
#  8   city                  100000 non-null  object
#  9   province              100000 non-null  object
#  10  ticket_price          100000 non-null  int64
#  11  visit_date            100000 non-null  object
#  12  visit_duration_hours  100000 non-null  float64
#  13  spend_amount          100000 non-null  float64
#  14  other_spend           100000 non-null  float64
#  15  rating                100000 non-null  float64
#  16  is_group_tour         100000 non-null  object
#  17  group_fee             29758 non-null   float64
#  18  trip_days             29758 non-null   float64
#  19  main_spots            29758 non-null   object
#  20  transport_mode        29758 non-null   object
#  21  season                100000 non-null  object
#  22  is_holiday            100000 non-null  object
#  23  recommendation_level  100000 non-null  object
#  24  satisfaction_level    100000 non-null  object
# dtypes: float64(6), int64(3), object(16)
# memory usage: 19.1+ MB
# None

# %%
# Show 10 Row (Overview of Dataset)
df.head(10)
# Out:
#    tourist_id  gender  age age_group source_province  \
# 0           1  Female   67       56+         Beijing
# 1           2    Male   22     18-25    Heilongjiang
# 2           3    Male   60       56+          Fujian
# 3           4  Female   33     26-35         Ningxia
# 4           5  Female   59       56+         Jiangxi
# 5           6    Male   22     18-25       Hong Kong
# 6           7  Female   25     18-25         Guangxi
# 7           8    Male   54     46-55          Hainan
# 8           9  Female   55     46-55  Inner Mongolia
# 9          10  Female   31     26-35         Beijing
#
#             attraction_name attraction_category attraction_level  \
# 0              Xuan Kong Si   Religious Culture               4A
# 1               Kai Feng Fu  Historical Culture               4A
# 2       Zhou Zhuang Gu Zhen        Ancient Town               5A
# 3      Zhu Jia Jiao Gu Zhen        Ancient Town               4A
# 4                   Lu Shan     Natural Culture               5A
# 5   Shang Rao Ji Zhong Ying  Revolutionary Site               4A
# 6     Ya Lu Jiang Duan Qiao  Revolutionary Site               4A
# 7   Bei Da Hu Hua Xue Chang    Sports & Leisure               4A
# 8       Zhong Guo Xue Xiang     Natural Scenery               4A
# 9  Fu Shun He Tu A La Cheng  Historical Culture               4A
#
#                city      province  ticket_price  visit_date  \
# 0       Da Tong Shi        Shanxi           125  2023/12/25
# 1      Kai Feng Shi         Henan            65  2024/11/14
# 2       Su Zhou Shi       Jiangsu           100   2022/7/20
# 3          Shanghai      Shanghai            60   2024/9/19
# 4     Jiu Jiang Shi       Jiangxi           160  2024/12/31
# 5     Shang Rao Shi       Jiangxi             0   2022/7/15
# 6      Dan Dong Shi      Liaoning            30    2022/5/4
# 7        Ji Lin Shi         Jilin           300    2022/7/1
# 8  Mu Dan Jiang Shi  Heilongjiang           120    2023/9/7
# 9       Fu Shun Shi      Liaoning            60    2024/3/2
#
#    visit_duration_hours  spend_amount  other_spend  rating is_group_tour  \
# 0                   6.3        361.52       236.52     4.3            No
# 1                   5.1         65.00         0.00     4.8            No
# 2                   6.1        469.27       369.27     4.4            No
# 3                   6.8         60.00         0.00     3.7            No
# 4                   2.9        160.00         0.00     4.9            No
# 5                   6.1        432.89       432.89     4.6            No
# 6                   3.4        413.97       383.97     4.3            No
# 7                   2.9        318.77        18.77     4.4            No
# 8                   3.6        265.11       145.11     4.2            No
# 9                   2.5        223.71       163.71     3.8            No
#
#    group_fee  trip_days main_spots transport_mode   season is_holiday  \
# 0        NaN        NaN        NaN            NaN   Winter         No
# 1        NaN        NaN        NaN            NaN   Autumn         No
# 2        NaN        NaN        NaN            NaN   Summer         No
# 3        NaN        NaN        NaN            NaN   Autumn         No
# 4        NaN        NaN        NaN            NaN   Winter         No
# 5        NaN        NaN        NaN            NaN   Summer         No
# 6        NaN        NaN        NaN            NaN  Chun Ji         No
# 7        NaN        NaN        NaN            NaN   Summer         No
# 8        NaN        NaN        NaN            NaN   Autumn         No
# 9        NaN        NaN        NaN            NaN  Chun Ji        Yes
#
#   recommendation_level satisfaction_level
# 0            Recommend          Satisfied
# 1     Highly Recommend     Very Satisfied
# 2            Recommend          Satisfied
# 3            Recommend          Satisfied
# 4     Highly Recommend     Very Satisfied
# 5     Highly Recommend     Very Satisfied
# 6            Recommend          Satisfied
# 7            Recommend          Satisfied
# 8            Recommend          Satisfied
# 9            Recommend          Satisfied

# %%
# Show Summary Statistic for Numerical Variable
print("\nNumerical stats:")
df.describe()
# Out:
# Numerical stats:
#           tourist_id            age   ticket_price  visit_duration_hours  \
# count  100000.000000  100000.000000  100000.000000         100000.000000
# mean     4747.806080      44.231390      80.783510              4.500496
# std      2835.294544      15.256722      67.183866              2.021727
# min         1.000000      18.000000       0.000000              1.000000
# 25%      2278.000000      31.000000      35.000000              2.700000
# 50%      4660.000000      44.000000      70.000000              4.500000
# 75%      7150.000000      57.000000     115.000000              6.300000
# max     10000.000000      70.000000     399.000000              8.000000
#
#         spend_amount    other_spend         rating     group_fee     trip_days
# count  100000.000000  100000.000000  100000.000000  29758.000000  29758.000000
# mean      255.433621     174.650111       4.431909   3045.056993      3.994321
# std       179.814679     166.584179       0.360680   2154.450339      2.013298
# min         0.000000       0.000000       3.100000    501.000000      1.000000
# 25%        98.000000       0.000000       4.200000   1234.000000      2.000000
# 50%       227.200000     141.880000       4.400000   2317.000000      4.000000
# 75%       401.090000     320.970000       4.700000   4689.000000      6.000000
# max       898.220000     500.000000       5.000000   7946.000000      7.000000

# %%
# Show Summary Statistic for Categorical Variable
print("\nCategorical stats:")
df.describe(include=['object'])
# Out:
# Categorical stats:
#         gender age_group source_province attraction_name attraction_category  \
# count   100000    100000          100000          100000              100000
# unique       2         5              34             431                  26
# top     Female       56+           Henan    Hu Kou Pu Bu     Natural Scenery
# freq     50161     28482            3353             452               36347
#
#        attraction_level      city  province visit_date is_group_tour  \
# count            100000    100000    100000     100000        100000
# unique                3       217        22       1096             2
# top                  4A  Shanghai  Zhejiang   2022/8/6            No
# freq              52383      4693      4767        119         70242
#
#                                                main_spots   transport_mode  \
# count                                               29758            29758
# unique                                                500                3
# top     Gu Bei Shui Zhen ,  Huang Shan ,  Shou Xi Hu ,...  Gao Tie + Da Ba
# freq                                                   82            10407
#
#         season is_holiday recommendation_level satisfaction_level
# count   100000     100000               100000             100000
# unique       4          2                    3                  3
# top     Summer         No            Recommend          Satisfied
# freq     25196      53565                50518              50518

# %%
# Detect Missing Value
# Missing Values Count per Column
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100
missing_df = pd.DataFrame({'Missing Count': missing, 'Percentage': missing_pct})
missing_df[missing_df['Missing Count'] > 0].sort_values('Missing Count', ascending=False)
# Out:
#                 Missing Count  Percentage
# group_fee               70242      70.242
# trip_days               70242      70.242
# main_spots              70242      70.242
# transport_mode          70242      70.242

# %%
# Check Unique Value
# Unique Values Count per Column
for col in df.columns:
    if col in ['tourist_id', 'age', 'ticket_price', 'visit_duration_hours', 'spend_amount', 'other_spend', 'rating', 'group_fee', 'trip_days']:
        continue
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# gender: 2 unique values
# age_group: 5 unique values
# source_province: 34 unique values
# attraction_name: 431 unique values
# attraction_category: 26 unique values
# attraction_level: 3 unique values
# city: 217 unique values
# province: 22 unique values
# visit_date: 1096 unique values
# is_group_tour: 2 unique values
# main_spots: 500 unique values
# transport_mode: 3 unique values
# season: 4 unique values
# is_holiday: 2 unique values
# recommendation_level: 3 unique values
# satisfaction_level: 3 unique values

# %%
# Sparsity
n_users = df['tourist_id'].nunique()
n_items = df['attraction_name'].nunique()
n_interactions = len(df)
possible = n_users * n_items
sparsity = 1 - (n_interactions / possible)

print(f"Unique Users: {n_users:,}")
print(f"Unique Attractions: {n_items:,}")
print(f"Interactions: {n_interactions:,}")
print(f"Possible Interactions: {possible:,}")
print(f"Sparsity: {sparsity*100:.2f}%")
# Out:
# Unique Users: 10,000
# Unique Attractions: 431
# Interactions: 100,000
# Possible Interactions: 4,310,000
# Sparsity: 97.68%

# %%
# Target Variable Summary
print("\n" + "="*60)
print("TARGET VARIABLE: rating (User Satisfaction Score)")
print("="*60)

# Summary Statistics
print("\n SUMMARY STATISTICS:")
print("-"*40)
print(df['rating'].describe())

# Value Counts (Binned)
print("\n VALUE COUNTS (Binned into 0.5-point ranges):")
print("-"*40)
bins = [3.0, 3.5, 4.0, 4.5, 5.0, 5.5]
labels = ['3.0-3.5', '3.5-4.0', '4.0-4.5', '4.5-5.0', '5.0+']
df['rating_binned'] = pd.cut(df['rating'], bins=bins, labels=labels, right=False)
print(df['rating_binned'].value_counts().sort_index())
# Out:
# ============================================================
# TARGET VARIABLE: rating (User Satisfaction Score)
# ============================================================
#
#  SUMMARY STATISTICS:
# ----------------------------------------
# count    100000.000000
# mean          4.431909
# std           0.360680
# min           3.100000
# 25%           4.200000
# 50%           4.400000
# 75%           4.700000
# max           5.000000
# Name: rating, dtype: float64
#
#  VALUE COUNTS (Binned into 0.5-point ranges):
# ----------------------------------------
# rating_binned
# 3.0-3.5      241
# 3.5-4.0     9778
# 4.0-4.5    40740
# 4.5-5.0    40137
# 5.0+        9104
# Name: count, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Histrogram to Show the Distribution of Target Variable
plt.figure(figsize=(10,5))
sns.histplot(df['rating'], bins=20, kde=True, color='steelblue')
plt.axvline(df['rating'].mean(), color='red', linestyle='--', label=f"Mean: {df['rating'].mean():.2f}")
plt.axvline(df['rating'].median(), color='green', linestyle='--', label=f"Median: {df['rating'].median():.2f}")
plt.title('Rating Distribution', fontsize=14)
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Bar Chart to Show the Distribution of Gender
plt.figure(figsize=(8,4))
df['gender'].value_counts().plot(kind='bar', color=['#ff6b6b', '#4d96ff'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# Bar Chart to Show the Distribution of Age Group
plt.figure(figsize=(10,4))
df['age_group'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title('Age Group Distribution')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# %%
# Bar Chart to Show the Distribution of Attraction Category
plt.figure(figsize=(10,5))
df['attraction_category'].value_counts().plot(kind='bar', color='lightcoral')
plt.title('Attraction Category Distribution')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar Chart to Show the Distribution of Attraction Level Category
plt.figure(figsize=(8,4))
df['attraction_level'].value_counts().plot(kind='bar', color=['#ffd93d', '#6bcb77', '#4d96ff'])
plt.title('Attraction Level Distribution')
plt.xlabel('Level')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# Bar Chart to Show the Top 10 Most Visited Attractions
plt.figure(figsize=(10,5))
df['attraction_name'].value_counts().head(10).plot(kind='barh', color='skyblue')
plt.title('Top 10 Most Visited Attractions')
plt.xlabel('Count')
plt.show()

# %%
# Bar Chart to Show the Season Distribution
plt.figure(figsize=(8,4))
season_order = ['Chun Ji', 'Summer', 'Autumn', 'Winter']
df['season'].value_counts().reindex(season_order).plot(kind='bar', color=['#ffd93d', '#ff6b6b', '#ffa94d', '#4d96ff'])
plt.title('Season Distribution')
plt.xlabel('Season')
plt.ylabel('Count')
plt.show()

# %%
# Pie Chart to Show the Porportion of Holiday vs Non-Holiday
plt.figure(figsize=(6,4))
df['is_holiday'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['#ff6b6b', '#6bcb77'])
plt.title('Holiday vs Non-Holiday')
plt.ylabel('')
plt.show()

# %%
# Histrogram to Show the Distribution of Visit Duration
plt.figure(figsize=(10,4))
sns.histplot(df['visit_duration_hours'], bins=20, kde=True, color='steelblue')
plt.axvline(df['visit_duration_hours'].mean(), color='red', linestyle='--', label=f"Mean: {df['visit_duration_hours'].mean():.1f}h")
plt.title('Visit Duration Distribution')
plt.xlabel('Hours')
plt.legend()
plt.show()

# %%
# Histrogram to Show the Distribution of Spending
plt.figure(figsize=(10,4))
sns.histplot(df['spend_amount'], bins=30, kde=True, color='lightcoral')
plt.axvline(df['spend_amount'].mean(), color='red', linestyle='--', label=f"Mean: ¥{df['spend_amount'].mean():.1f}")
plt.title('Spending Distribution')
plt.xlabel('Amount (CNY)')
plt.legend()
plt.show()

# %%
# Pie Chart to Show the Porportion of Group Tour vs Independent
plt.figure(figsize=(6,4))
df['is_group_tour'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['#6bcb77', '#ff6b6b'])
plt.title('Group Tour vs Independent')
plt.ylabel('')
plt.show()

# %%
# Boxplot: Rating vs Season
plt.figure(figsize=(8,4))
sns.boxplot(data=df, x='season', y='rating', hue='season', 
            order=['Chun Ji', 'Summer', 'Autumn', 'Winter'], 
            palette='Set2', legend=False)
plt.title('Rating by Season')
plt.xlabel('Season')
plt.ylabel('Rating')
plt.show()

# %%
# Boxplot: Rating vs Attrative Level
plt.figure(figsize=(8,4))
sns.boxplot(data=df, x='attraction_level', y='rating', hue='attraction_level', 
            palette='Set2', legend=False)
plt.title('Rating by Attraction Level')
plt.xlabel('Attraction Level')
plt.ylabel('Rating')
plt.show()

# %%
# Boxplot: Rating vs Age Group
plt.figure(figsize=(10,4))
age_order = ['18-25', '26-35', '36-45', '46-55', '56+']
sns.boxplot(data=df, x='age_group', y='rating', hue='age_group', 
            order=age_order, palette='Set2', legend=False)
plt.title('Rating by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Rating')
plt.show()

# %%
# User Activity
user_activity = df.groupby('tourist_id').size()
print(f"\nAverage interactions per user: {user_activity.mean():.2f}")
print(f"Median interactions per user: {user_activity.median():.2f}")

plt.figure(figsize=(10,4))
sns.histplot(user_activity, bins=20, kde=True, color='steelblue')
plt.axvline(user_activity.mean(), color='red', linestyle='--', label=f"Mean: {user_activity.mean():.1f}")
plt.axvline(user_activity.median(), color='green', linestyle='--', label=f"Median: {user_activity.median():.1f}")
plt.title('User Activity Distribution')
plt.xlabel('Number of Interactions per User')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# Average interactions per user: 10.00
# Median interactions per user: 10.00

# %%
# Item Popularity
item_popularity = df.groupby('attraction_name').size()
print(f"\nAverage interactions per attraction: {item_popularity.mean():.2f}")
print(f"Median interactions per attraction: {item_popularity.median():.2f}")

plt.figure(figsize=(10,4))
sns.histplot(item_popularity, bins=20, kde=True, color='lightcoral')
plt.axvline(item_popularity.mean(), color='red', linestyle='--', label=f"Mean: {item_popularity.mean():.1f}")
plt.axvline(item_popularity.median(), color='green', linestyle='--', label=f"Median: {item_popularity.median():.1f}")
plt.title('Item Popularity Distribution')
plt.xlabel('Number of Interactions per Attraction')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# Average interactions per attraction: 232.02
# Median interactions per attraction: 232.00

# %% [markdown]
# ## Data Preprocessing

# %%
# Identify Useless Column 
print("\n" + "="*60)
print("IDENTIFY USELESS COLUMNS")
print("="*60)

# Analyze Columns that Might Be Useless
useless_cols_analysis = []

for col in df.columns:
    if col in ['tourist_id', 'attraction_name', 'rating']:
        continue
    
    missing_pct = df[col].isnull().sum() / len(df) * 100
    unique_count = df[col].nunique()
    
    # For Numerical Columns, Check If It's Mostly The Same Value
    if df[col].dtype in ['int64', 'float64']:
        most_common_pct = df[col].value_counts(normalize=True).max() * 100
        is_constant = most_common_pct > 95
    else:
        most_common_pct = df[col].value_counts(normalize=True).max() * 100
        is_constant = most_common_pct > 95
    
    useless_cols_analysis.append({
        'Column': col,
        'Data Type': df[col].dtype,
        'Missing %': missing_pct,
        'Unique Values': unique_count,
        'Most Common %': most_common_pct,
        'Is Constant': is_constant
    })

useless_df = pd.DataFrame(useless_cols_analysis)
print(useless_df.to_string(index=False))
# Out:
# ============================================================
# IDENTIFY USELESS COLUMNS
# ============================================================
#               Column Data Type  Missing %  Unique Values  Most Common %  Is Constant
#               gender    object      0.000              2      50.161000        False
#                  age     int64      0.000             53       2.293000        False
#            age_group    object      0.000              5      28.482000        False
#      source_province    object      0.000             34       3.353000        False
#  attraction_category    object      0.000             26      36.347000        False
#     attraction_level    object      0.000              3      52.383000        False
#                 city    object      0.000            217       4.693000        False
#             province    object      0.000             22       4.767000        False
#         ticket_price     int64      0.000             75      16.907000        False
#           visit_date    object      0.000           1096       0.119000        False
# visit_duration_hours   float64      0.000             71       1.516000        False
#         spend_amount   float64      0.000          41398       4.969000        False
#          other_spend   float64      0.000          37662      30.009000        False
#        is_group_tour    object      0.000              2      70.242000        False
#            group_fee   float64     70.242            477       0.584717        False
#            trip_days   float64     70.242              7      14.796021        False
#           main_spots    object     70.242            500       0.275556        False
#       transport_mode    object     70.242              3      34.972108        False
#               season    object      0.000              4      25.196000        False
#           is_holiday    object      0.000              2      53.565000        False
# recommendation_level    object      0.000              3      50.518000        False
#   satisfaction_level    object      0.000              3      50.518000        False
#        rating_binned  category      0.000              5      40.740000        False

# %%
# Drop Useless Columns
print("\n" + "="*60)
print("DROPPING USELESS COLUMNS")
print("="*60)

# List of Columns to Drop
columns_to_drop = []

# Columns With >80% missing
for col in df.columns:
    if df[col].isnull().sum() / len(df) > 0.8:
        columns_to_drop.append(col)

# Constant Columns
for col in df.columns:
    if df[col].dtype in ['int64', 'float64', 'object']:
        if df[col].value_counts(normalize=True).max() > 0.95:
            columns_to_drop.append(col)

# Columns Specifically for Group Tours (Too Sparse)
group_tour_cols = ['group_fee', 'trip_days', 'main_spots', 'transport_mode']
for col in group_tour_cols:
    if col in df.columns:
        columns_to_drop.append(col)

# Remove Duplicates from Drop List
columns_to_drop = list(set(columns_to_drop))

print(f"\nColumns to be dropped ({len(columns_to_drop)}):")
for col in sorted(columns_to_drop):
    if col in df.columns:
        print(f"   - {col} (missing: {df[col].isnull().sum()/len(df)*100:.1f}%)")
    else:
        print(f"   - {col} (already dropped)")

# Drop columns
df_cleaned = df.drop(columns=columns_to_drop, errors='ignore')

print(f"\nBefore dropping: {df.shape[1]} columns")
print(f"After dropping: {df_cleaned.shape[1]} columns")
print(f"Dropped: {df.shape[1] - df_cleaned.shape[1]} columns")

# Show Remaining Columns
print("\n Remaining columns:")
for col in df_cleaned.columns:
    print(f"   - {col}")
# Out:
# ============================================================
# DROPPING USELESS COLUMNS
# ============================================================
#
# Columns to be dropped (4):
#    - group_fee (missing: 70.2%)
#    - main_spots (missing: 70.2%)
#    - transport_mode (missing: 70.2%)
#    - trip_days (missing: 70.2%)
#
# Before dropping: 26 columns
# After dropping: 22 columns
# Dropped: 4 columns
#
#  Remaining columns:
#    - tourist_id
#    - gender
#    - age
#    - age_group
#    - source_province
#    - attraction_name
#    - attraction_category
#    - attraction_level
#    - city
#    - province
#    - ticket_price
#    - visit_date
#    - visit_duration_hours
#    - spend_amount
#    - other_spend
#    - rating
#    - is_group_tour
#    - season
#    - is_holiday
#    - recommendation_level
#    - satisfaction_level
#    - rating_binned

# %%
print("\n" + "="*60)
print("HANDLING MISSING VALUES")
print("="*60)

# Check Missing Values in Cleaned Dataset
print("\nMissing Values in Cleaned Dataset:")
missing = df_cleaned.isnull().sum()
missing_pct = (missing / len(df_cleaned)) * 100
missing_df = pd.DataFrame({'Missing Count': missing, 'Percentage': missing_pct})
missing_df = missing_df[missing_df['Missing Count'] > 0].sort_values('Missing Count', ascending=False)

print(missing_df)

# Visualize Missing Values
if len(missing_df) > 0:
    plt.figure(figsize=(10, 6))
    plt.barh(missing_df.index, missing_df['Missing Count'], color='steelblue')
    plt.title('Missing Values ', fontsize=14)
    plt.xlabel('Number of Missing Values')
    plt.tight_layout()
    plt.savefig('missing_values.png', dpi=100)
    plt.show()
else:
    print("\nNo missing values found!")
# Out:
# ============================================================
# HANDLING MISSING VALUES
# ============================================================
#
# Missing Values in Cleaned Dataset:
# Empty DataFrame
# Columns: [Missing Count, Percentage]
# Index: []
#
# No missing values found!

# %%
print("\n" + "="*60)
print("HANDLING MISSING VALUES (IMPUTATION)")
print("="*60)

df_final = df_cleaned.copy()

# Strategy: Fill missing values appropriately
for col in df_final.columns:
    missing_pct = df_final[col].isnull().sum() / len(df_final) * 100
    
    if missing_pct > 0:
        print(f"\nColumn: {col} (missing: {missing_pct:.1f}%)")
        
        if df_final[col].dtype in ['int64', 'float64']:
            # Numerical: fill with median
            median_val = df_final[col].median()
            df_final[col].fillna(median_val, inplace=True)
            print(f"   Filled with median: {median_val:.2f}")
        else:
            # Categorical: fill with mode
            mode_val = df_final[col].mode()[0]
            df_final[col].fillna(mode_val, inplace=True)
            print(f"   Filled with mode: {mode_val}")

# Verify no missing values remain
print("\n Missing values after imputation:")
print(df_final.isnull().sum().sum())
print(df_final.isnull().sum())
# Out:
# ============================================================
# HANDLING MISSING VALUES (IMPUTATION)
# ============================================================
#
#  Missing values after imputation:
# 0
# tourist_id              0
# gender                  0
# age                     0
# age_group               0
# source_province         0
#                        ..
# season                  0
# is_holiday              0
# recommendation_level    0
# satisfaction_level      0
# rating_binned           0
# Length: 22, dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
from sklearn.preprocessing import StandardScaler, OrdinalEncoder

print("\n" + "="*60)
print("FEATURE ENGINEERING")
print("="*60)

# Handle Dates (Extract Month & Day)
df_cleaned['visit_date'] = pd.to_datetime(df_cleaned['visit_date'])
df_cleaned['visit_month'] = df_cleaned['visit_date'].dt.month
df_cleaned['visit_day_of_week'] = df_cleaned['visit_date'].dt.dayofweek
df_cleaned = df_cleaned.drop(columns=['visit_date'])

# Standardize numerical features
num_cols = ['age', 'ticket_price', 'visit_duration_hours', 'spend_amount', 'other_spend']
scaler = StandardScaler()
df_cleaned[num_cols] = scaler.fit_transform(df_cleaned[num_cols])

# Ordinal Encoding (Order matters)
ordinal_mapping = {
    'attraction_level': ['3A', '4A', '5A'],
    'satisfaction_level': ['Neutral', 'Satisfied', 'Very Satisfied'],
    'recommendation_level': ['Neutral', 'Recommend', 'Highly Recommend']
}
for col, categories in ordinal_mapping.items():
    encoder = OrdinalEncoder(categories=[categories])
    df_cleaned[col] = encoder.fit_transform(df_cleaned[[col]])

# Shift User ID to start at 0 (Required for Collaborative Filtering)
df_cleaned['tourist_id'] = df_cleaned['tourist_id'] - 1

# One-Hot Encoding for Nominal Categories (The fix for MLPRegressor)
categorical_cols = [
    'gender', 'age_group', 'source_province', 'attraction_name', 
    'attraction_category', 'city', 'province', 'is_group_tour', 'season', 'is_holiday'
]
# drop_first=True prevents perfect multicollinearity (dummy variable trap)
df_final = pd.get_dummies(df_cleaned, columns=categorical_cols, drop_first=True)

# Prevent Data Leakage (Separate features and target)
y = df_final['rating']
X = df_final.drop(columns=['rating', 'satisfaction_level', 'recommendation_level'])

print(df_final.head())
# Out:
# ============================================================
# FEATURE ENGINEERING
# ============================================================
#    tourist_id       age  attraction_level  ticket_price  visit_duration_hours  \
# 0           0  1.492373               1.0      0.658145              0.890087
# 1           1 -1.457161               1.0     -0.234931              0.296532
# 2           2  1.033557               2.0      0.286030              0.791161
# 3           3 -0.736164               1.0     -0.309354              1.137402
# 4           4  0.968012               2.0      1.179106             -0.791652
#
#    spend_amount  other_spend  rating  recommendation_level  \
# 0      0.589979     0.371405     4.3                   1.0
# 1     -1.059060    -1.048425     4.8                   2.0
# 2      1.189210     1.168303     4.4                   1.0
# 3     -1.086867    -1.048425     3.7                   1.0
# 4     -0.530736    -1.048425     4.9                   2.0
#
#    satisfaction_level rating_binned  visit_month  visit_day_of_week  \
# 0                 1.0       4.0-4.5           12                  0
# 1                 2.0       4.5-5.0           11                  3
# 2                 1.0       4.0-4.5            7                  2
# 3                 1.0       3.5-4.0            9                  3
# 4                 2.0       4.5-5.0           12                  1
#
#    gender_Male  age_group_26-35  age_group_36-45  age_group_46-55  \
# 0        False            False            False            False
# 1         True            False            False            False
# 2         True            False            False            False
# 3        False             True            False            False
# 4        False            False            False            False
#
#    age_group_56+  source_province_Beijing  source_province_Chongqing  \
# 0           True                     True                      False
# 1          False                    False                      False
# 2           True                    False                      False
# 3          False                    False                      False
# 4           True                    False                      False
#
#    source_province_Fujian  source_province_Gansu  source_province_Guangdong  \
# 0                   False                  False                      False
# 1                   False                  False                      False
# 2                    True                  False                      False
# 3                   False                  False                      False
# 4                   False                  False                      False
#
#    source_province_Guangxi  source_province_Guizhou  source_province_Hainan  \
# 0                    False                    False                   False
# 1                    False                    False                   False
# 2                    False                    False                   False
# 3                    False                    False                   False
# 4                    False                    False                   False
#
#    source_province_Hebei  source_province_Heilongjiang  source_province_Henan  \
# 0                  False                         False                  False
# 1                  False                          True                  False
# 2                  False                         False                  False
# 3                  False                         False                  False
# 4                  False                         False                  False
#
#    source_province_Hong Kong  source_province_Hubei  source_province_Hunan  \
# 0                      False                  False                  False
# 1                      False                  False                  False
# 2                      False                  False                  False
# 3                      False                  False                  False
# 4                      False                  False                  False
#
#    source_province_Inner Mongolia  source_province_Jiangsu  \
# 0                           False                    False
# 1                           False                    False
# 2                           False                    False
# 3                           False                    False
# 4                           False                    False
#
#    source_province_Jiangxi  source_province_Jilin  source_province_Liaoning  \
# 0                    False                  False                     False
# 1                    False                  False                     False
# 2                    False                  False                     False
# 3                    False                  False                     False
# 4                     True                  False                     False
#
#    source_province_Macau  source_province_Ningxia  source_province_Qinghai  \
# 0                  False                    False                    False
# 1                  False                    False                    False
# 2                  False                    False                    False
# 3                  False                     True                    False
# 4                  False                    False                    False
#
#    source_province_Shaanxi  source_province_Shandong  \
# 0                    False                     False
# 1                    False                     False
# 2                    False                     False
# 3                    False                     False
# 4                    False                     False
#
#    source_province_Shanghai  source_province_Shanxi  source_province_Sichuan  \
# 0                     False                   False                    False
# 1                     False                   False                    False
# 2                     False                   False                    False
# 3                     False                   False                    False
# 4                     False                   False                    False
#
#    source_province_Taiwan  source_province_Tianjin  source_province_Tibet  \
# 0                   False                    False                  False
# 1                   False                    False                  False
# 2                   False                    False                  False
# 3                   False                    False                  False
# 4                   False                    False                  False
#
#    source_province_Xinjiang  source_province_Yunnan  source_province_Zhejiang  \
# 0                     False                   False                     False
# 1                     False                   False                     False
# 2                     False                   False                     False
# 3                     False                   False                     False
# 4                     False                   False                     False
#
#    attraction_name_An Qing Zhen Feng Ta  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    attraction_name_An Yuan Lu Kuang Gong Ren Yun Dong Ji Nian Guan  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    attraction_name_Ba Da Ling Chang Cheng  attraction_name_Ba Li Gou  \
# 0                                   False                      False
# 1                                   False                      False
# 2                                   False                      False
# 3                                   False                      False
# 4                                   False                      False
#
#    attraction_name_Ba Li He  attraction_name_Bai Ma Si  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
#
#    attraction_name_Bai Se Qi Yi Ji Nian Guan  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    attraction_name_Bai Shan Chang Bai Shan Da Xia Gu  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    attraction_name_Bai Shi Shan  attraction_name_Bai Shui Yang  \
# 0                         False                          False
# 1                         False                          False
# 2                         False                          False
# 3                         False                          False
# 4                         False                          False
#
#    attraction_name_Bai Yang Dian  attraction_name_Bai Yun Shan  \
# 0                          False                         False
# 1                          False                         False
# 2                          False                         False
# 3                          False                         False
# 4                          False                         False
#
#    attraction_name_Bao Tu Quan  attraction_name_Bei Da Hu Hua Xue Chang  \
# 0                        False                                    False
# 1                        False                                    False
# 2                        False                                    False
# 3                        False                                    False
# 4                        False                                    False
#
#    attraction_name_Bei Dai He  attraction_name_Bei Hai Gong Yuan  \
# 0                       False                              False
# 1                       False                              False
# 2                       False                              False
# 3                       False                              False
# 4                       False                              False
#
#    attraction_name_Bei Hai Yin Tan  attraction_name_Bei Jing Dong Wu Yuan  \
# 0                            False                                  False
# 1                            False                                  False
# 2                            False                                  False
# 3                            False                                  False
# 4                            False                                  False
#
#    attraction_name_Bei Jing Huan Le Gu  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
#
#    attraction_name_Bei Jing Ye Sheng Dong Wu Yuan  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    attraction_name_Bei Jing Zhi Wu Yuan  attraction_name_Ben Xi Shui Dong  \
# 0                                 False                             False
# 1                                 False                             False
# 2                                 False                             False
# 3                                 False                             False
# 4                                 False                             False
#
#    attraction_name_Bing Lang Gu  attraction_name_Bo Zhou Hua Xi Lou  \
# 0                         False                               False
# 1                         False                               False
# 2                         False                               False
# 3                         False                               False
# 4                         False                               False
#
#    attraction_name_Cai Shi Ji  attraction_name_Cha Gan Hu  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    attraction_name_Cha Ya Shan  attraction_name_Chang Bai Shan  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
#
#    attraction_name_Chang Chun Dian Ying Zhi Pian Chang  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    attraction_name_Chang Chun Shi Jie Diao Su Yuan  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    attraction_name_Chang Jia Zhuang Yuan  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    attraction_name_Chang Sha Shi Jie Zhi Chuang  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    attraction_name_Chang Zhou Zhong Hua Kong Long Yuan  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    attraction_name_Chao Hu  attraction_name_Chao Zhou Guang Ji Qiao  \
# 0                    False                                    False
# 1                    False                                    False
# 2                    False                                    False
# 3                    False                                    False
# 4                    False                                    False
#
#    attraction_name_Chen Jia Ci  attraction_name_Cheng De Bi Shu Shan Zhuang  \
# 0                        False                                        False
# 1                        False                                        False
# 2                        False                                        False
# 3                        False                                        False
# 4                        False                                        False
#
#    attraction_name_Cheng Du Da Xiong Mao Fan Yu Ji Di  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    attraction_name_Chong Sheng Si San Ta  attraction_name_Da Jue Shan  \
# 0                                  False                        False
# 1                                  False                        False
# 2                                  False                        False
# 3                                  False                        False
# 4                                  False                        False
#
#    attraction_name_Da Li Gu Cheng  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
#    attraction_name_Da Lian Lao Hu Tan Hai Yang Gong Yuan  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    attraction_name_Da Lian Sen Lin Dong Wu Yuan  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    attraction_name_Da Lian Xing Hai Guang Chang  attraction_name_Da Ming Hu  \
# 0                                         False                       False
# 1                                         False                       False
# 2                                         False                       False
# 3                                         False                       False
# 4                                         False                       False
#
#    attraction_name_Da Qing Tie Ren Ji Nian Guan  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    attraction_name_Da Tang Fu Rong Yuan  attraction_name_Da Tong Huo Shan Qun  \
# 0                                 False                                 False
# 1                                 False                                 False
# 2                                 False                                 False
# 3                                 False                                 False
# 4                                 False                                 False
#
#    attraction_name_Da Xing An Ling Mo He Bei Ji Cun  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    attraction_name_Da Yan Ta  attraction_name_Dan Dong Feng Huang Shan  \
# 0                      False                                     False
# 1                      False                                     False
# 2                      False                                     False
# 3                      False                                     False
# 4                      False                                     False
#
#    attraction_name_Dan Xia Shan  attraction_name_Dao Cheng Ya Ding  \
# 0                         False                              False
# 1                         False                              False
# 2                         False                              False
# 3                         False                              False
# 4                         False                              False
#
#    attraction_name_De Hang Da Xia Gu  attraction_name_De Tian Pu Bu  \
# 0                              False                          False
# 1                              False                          False
# 2                              False                          False
# 3                              False                          False
# 4                              False                          False
#
#    attraction_name_De Zhou Tai Yang Gu  attraction_name_Dian Chi  \
# 0                                False                     False
# 1                                False                     False
# 2                                False                     False
# 3                                False                     False
# 4                                False                     False
#
#    attraction_name_Dong Bei Hu Lin Yuan  attraction_name_Dong Fang Ming Zhu  \
# 0                                 False                               False
# 1                                 False                               False
# 2                                 False                               False
# 3                                 False                               False
# 4                                 False                               False
#
#    attraction_name_Dong Guan Ke Yuan  attraction_name_Dong Hu  \
# 0                              False                    False
# 1                              False                    False
# 2                              False                    False
# 3                              False                    False
# 4                              False                    False
#
#    attraction_name_Dong Jiang Hu  attraction_name_Dong Lin Si  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
#
#    attraction_name_Du Fu Cao Tang  attraction_name_Du Jiang Yan  \
# 0                           False                         False
# 1                           False                         False
# 2                           False                         False
# 3                           False                         False
# 4                           False                         False
#
#    attraction_name_E Mei Shan  attraction_name_E Zhou Liang Zi Hu  \
# 0                       False                               False
# 1                       False                               False
# 2                       False                               False
# 3                       False                               False
# 4                       False                               False
#
#    attraction_name_En Shi Da Xia Gu  attraction_name_Fa Men Si  \
# 0                             False                      False
# 1                             False                      False
# 2                             False                      False
# 3                             False                      False
# 4                             False                      False
#
#    attraction_name_Fang Cheng Gang Shi Wan Da Shan  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    attraction_name_Fang Chuan Feng Jing Qu  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    attraction_name_Fang Te Huan Le Shi Jie  attraction_name_Fen Jie Zhou Dao  \
# 0                                    False                             False
# 1                                    False                             False
# 2                                    False                             False
# 3                                    False                             False
# 4                                    False                             False
#
#    attraction_name_Feng Huang Gu Cheng  attraction_name_Fu Jian Tu Lou  \
# 0                                False                           False
# 1                                False                           False
# 2                                False                           False
# 3                                False                           False
# 4                                False                           False
#
#    attraction_name_Fu Rong Zhen  attraction_name_Fu Shun He Tu A La Cheng  \
# 0                         False                                     False
# 1                         False                                     False
# 2                         False                                     False
# 3                         False                                     False
# 4                         False                                     False
#
#    attraction_name_Fu Xian Hu  attraction_name_Fu Xin Hai Tang Shan  \
# 0                       False                                 False
# 1                       False                                 False
# 2                       False                                 False
# 3                       False                                 False
# 4                       False                                 False
#
#    attraction_name_Fu Zhou Gu Shan  attraction_name_Fu Zhou San Shan Liang Ta  \
# 0                            False                                      False
# 1                            False                                      False
# 2                            False                                      False
# 3                            False                                      False
# 4                            False                                      False
#
#    attraction_name_Fu Zi Miao Qin Huai Feng Guang Dai  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    attraction_name_Gao Ju Li Yi Zhi  attraction_name_Gong Wang Fu  \
# 0                             False                         False
# 1                             False                         False
# 2                             False                         False
# 3                             False                         False
# 4                             False                         False
#
#    attraction_name_Gu Bei Shui Zhen  attraction_name_Gu Gong Bo Wu Yuan  \
# 0                             False                               False
# 1                             False                               False
# 2                             False                               False
# 3                             False                               False
# 4                             False                               False
#
#    attraction_name_Gu Hui Zhou Wen Hua Lv You Qu  attraction_name_Gu Lang Yu  \
# 0                                          False                       False
# 1                                          False                       False
# 2                                          False                       False
# 3                                          False                       False
# 4                                          False                       False
#
#    attraction_name_Guan Lin  attraction_name_Guang Fu Gu Cheng  \
# 0                     False                              False
# 1                     False                              False
# 2                     False                              False
# 3                     False                              False
# 4                     False                              False
#
#    attraction_name_Guang Zhou Ta  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
#    attraction_name_Guang Zhou Zhang Long Lv You Du Jia Qu  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    attraction_name_Gui Feng  attraction_name_Gui Gang Gui Ping Xi Shan  \
# 0                     False                                      False
# 1                     False                                      False
# 2                     False                                      False
# 3                     False                                      False
# 4                     False                                      False
#
#    attraction_name_Gui Lin Li Jiang  \
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#
#    attraction_name_Gui Lin Liang Jiang Si Hu  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    attraction_name_Gui Lin Xiang Bi Shan  attraction_name_Guo Jia Bo Wu Guan  \
# 0                                  False                               False
# 1                                  False                               False
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
#
#    attraction_name_Ha Er Bin Bing Xue Da Shi Jie  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    attraction_name_Hai Kou Huo Shan Kou  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    attraction_name_Hai Kou Qi Lou Lao Jie  attraction_name_Hai Luo Gou  \
# 0                                   False                        False
# 1                                   False                        False
# 2                                   False                        False
# 3                                   False                        False
# 4                                   False                        False
#
#    attraction_name_Han Yang Ling  attraction_name_Hang Zhou Song Cheng  \
# 0                          False                                 False
# 1                          False                                 False
# 2                          False                                 False
# 3                          False                                 False
# 4                          False                                 False
#
#    attraction_name_Hang Zhou Xi Hu  attraction_name_Hang Zhou Xi Xi Shi Di  \
# 0                            False                                   False
# 1                            False                                   False
# 2                            False                                   False
# 3                            False                                   False
# 4                            False                                   False
#
#    attraction_name_He Chi Ba Ma Chang Shou Cun  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    attraction_name_He Gang Luo Bei Ming Shan Dao  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    attraction_name_He Shun Gu Zhen  attraction_name_He Zhou Huang Yao Gu Zhen  \
# 0                            False                                      False
# 1                            False                                      False
# 2                            False                                      False
# 3                            False                                      False
# 4                            False                                      False
#
#    attraction_name_Hei He Ai Hui Gu Cheng  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    attraction_name_Heng Dian Ying Shi Cheng  attraction_name_Heng Shui Hu  \
# 0                                     False                         False
# 1                                     False                         False
# 2                                     False                         False
# 3                                     False                         False
# 4                                     False                         False
#
#    attraction_name_Hong Dong Da Huai Shu  attraction_name_Hong Hai Tan  \
# 0                                  False                         False
# 1                                  False                         False
# 2                                  False                         False
# 3                                  False                         False
# 4                                  False                         False
#
#    attraction_name_Hong Qi Qu  attraction_name_Hu Kou Pu Bu  \
# 0                       False                         False
# 1                       False                         False
# 2                       False                         False
# 3                       False                         False
# 4                       False                         False
#
#    attraction_name_Hu Lu Dao Xing Cheng Gu Cheng  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    attraction_name_Hu Nan Sheng Bo Wu Guan  attraction_name_Hu Tiao Xia  \
# 0                                    False                        False
# 1                                    False                        False
# 2                                    False                        False
# 3                                    False                        False
# 4                                    False                        False
#
#    attraction_name_Hua Guo Shan  attraction_name_Hua Qing Gong  \
# 0                         False                          False
# 1                         False                          False
# 2                         False                          False
# 3                         False                          False
# 4                         False                          False
#
#    attraction_name_Hua Shan  attraction_name_Hua Shan Mi Ku  \
# 0                     False                           False
# 1                     False                           False
# 2                     False                           False
# 3                     False                           False
# 4                     False                           False
#
#    attraction_name_Huang Cheng Xiang Fu  attraction_name_Huang Di Ling  \
# 0                                 False                          False
# 1                                 False                          False
# 2                                 False                          False
# 3                                 False                          False
# 4                                 False                          False
#
#    attraction_name_Huang He Feng Jing Qu  attraction_name_Huang He Lou  \
# 0                                  False                         False
# 1                                  False                         False
# 2                                  False                         False
# 3                                  False                         False
# 4                                  False                         False
#
#    attraction_name_Huang Long  attraction_name_Huang Shan  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    attraction_name_Huang Shi Guo Jia Kuang Shan Gong Yuan  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    attraction_name_Hui Min Jie  attraction_name_Hui Zhou Xi Hu  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
#
#    attraction_name_Ji Gong Shan  attraction_name_Ji Lin Bei Shan  \
# 0                         False                            False
# 1                         False                            False
# 2                         False                            False
# 3                         False                            False
# 4                         False                            False
#
#    attraction_name_Ji Xi Xing Kai Hu  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    attraction_name_Jia Mu Si Tong Jiang San Jiang Kou  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    attraction_name_Jia Xing Nan Hu  attraction_name_Jian Men Guan  \
# 0                            False                          False
# 1                            False                          False
# 2                            False                          False
# 3                            False                          False
# 4                            False                          False
#
#    attraction_name_Jian Shui Gu Cheng  attraction_name_Jin Ci  \
# 0                               False                   False
# 1                               False                   False
# 2                               False                   False
# 3                               False                   False
# 4                               False                   False
#
#    attraction_name_Jin Ji Hu  attraction_name_Jin Li  \
# 0                      False                   False
# 1                      False                   False
# 2                      False                   False
# 3                      False                   False
# 4                      False                   False
#
#    attraction_name_Jin Shan Ling Chang Cheng  attraction_name_Jin Shi Tan  \
# 0                                      False                        False
# 1                                      False                        False
# 2                                      False                        False
# 3                                      False                        False
# 4                                      False                        False
#
#    attraction_name_Jin Si Xia  attraction_name_Jin Zhou Bi Jia Shan  \
# 0                       False                                 False
# 1                       False                                 False
# 2                       False                                 False
# 3                       False                                 False
# 4                       False                                 False
#
#    attraction_name_Jing De Zhen Gu Yao  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
#
#    attraction_name_Jing De Zhen Tao Ci Bo Wu Guan  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    attraction_name_Jing Gang Shan  attraction_name_Jing Men Ming Xian Ling  \
# 0                           False                                    False
# 1                           False                                    False
# 2                           False                                    False
# 3                           False                                    False
# 4                           False                                    False
#
#    attraction_name_Jing Po Hu  attraction_name_Jing Yue Tan  \
# 0                       False                         False
# 1                       False                         False
# 2                       False                         False
# 3                       False                         False
# 4                       False                         False
#
#    attraction_name_Jing Zhou Gu Cheng  attraction_name_Jiu Hua Shan  \
# 0                               False                         False
# 1                               False                         False
# 2                               False                         False
# 3                               False                         False
# 4                               False                         False
#
#    attraction_name_Jiu Yi Ba Li Shi Bo Wu Guan  attraction_name_Jiu Zhai Gou  \
# 0                                        False                         False
# 1                                        False                         False
# 2                                        False                         False
# 3                                        False                         False
# 4                                        False                         False
#
#    attraction_name_Ju Zi Zhou  attraction_name_Kai Feng Fu  \
# 0                       False                        False
# 1                       False                         True
# 2                       False                        False
# 3                       False                        False
# 4                       False                        False
#
#    attraction_name_Kai Ping Diao Lou  attraction_name_Kuan Zhai Xiang Zi  \
# 0                              False                               False
# 1                              False                               False
# 2                              False                               False
# 3                              False                               False
# 4                              False                               False
#
#    attraction_name_Kun Ming Shi Bo Yuan  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    attraction_name_Lai Bin Jin Xiu Sheng Tang Shan  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    attraction_name_Lang Fang Tian Xia Di Yi Cheng  attraction_name_Lang Shan  \
# 0                                           False                      False
# 1                                           False                      False
# 2                                           False                      False
# 3                                           False                      False
# 4                                           False                      False
#
#    attraction_name_Lang Ya Shan  attraction_name_Lang Zhong Gu Cheng  \
# 0                         False                                False
# 1                         False                                False
# 2                         False                                False
# 3                         False                                False
# 4                         False                                False
#
#    attraction_name_Lao Jun Shan  attraction_name_Lao Shan  \
# 0                         False                     False
# 1                         False                     False
# 2                         False                     False
# 3                         False                     False
# 4                         False                     False
#
#    attraction_name_Le Shan Da Fu  attraction_name_Li Jiang Gu Cheng  \
# 0                          False                              False
# 1                          False                              False
# 2                          False                              False
# 3                          False                              False
# 4                          False                              False
#
#    attraction_name_Li Shui Yun He Ti Tian  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    attraction_name_Liao Cheng Dong Chang Hu  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    attraction_name_Liao Yang Guang You Si  \
# 0                                   False
# 1                                   False
# ...
# 2               False              False              False
# 3               False              False              False
# 4               False              False              False
#
#    city_Nan Ping Shi  city_Nan Tong Shi  city_Ning Bo Shi  city_Ning De Shi  \
# 0              False              False             False             False
# 1              False              False             False             False
# 2              False              False             False             False
# 3              False              False             False             False
# 4              False              False             False             False
#
#    city_Pan Jin Shi  city_Ping Xiang Shi  city_Pu Tian Shi  \
# 0             False                False             False
# 1             False                False             False
# 2             False                False             False
# 3             False                False             False
# 4             False                False             False
#
#    city_Qi Qi Ha Er Shi  city_Qi Tai He Shi  city_Qian Jiang Shi  \
# 0                 False               False                False
# 1                 False               False                False
# 2                 False               False                False
# 3                 False               False                False
# 4                 False               False                False
#
#    city_Qin Huang Dao Shi  city_Qin Zhou Shi  city_Qing Dao Shi  \
# 0                   False              False              False
# 1                   False              False              False
# 2                   False              False              False
# 3                   False              False              False
# 4                   False              False              False
#
#    city_Qiong Hai Shi  city_Qu Zhou Shi  city_Quan Zhou Shi  city_Ri Zhao Shi  \
# 0               False             False               False             False
# 1               False             False               False             False
# 2               False             False               False             False
# 3               False             False               False             False
# 4               False             False               False             False
#
#    city_San Ming Shi  city_San Ya Shi  city_Shang Luo Shi  city_Shang Qiu Shi  \
# 0              False            False               False               False
# 1              False            False               False               False
# 2              False            False               False               False
# 3              False            False               False               False
# 4              False            False               False               False
#
#    city_Shang Rao Shi  city_Shanghai  city_Shao Guan Shi  city_Shao Xing Shi  \
# 0               False          False               False               False
# 1               False          False               False               False
# 2               False          False               False               False
# 3               False           True               False               False
# 4               False          False               False               False
#
#    city_Shao Yang Shi  city_Shen Nong Jia Lin Qu  city_Shen Yang Shi  \
# 0               False                      False               False
# 1               False                      False               False
# 2               False                      False               False
# 3               False                      False               False
# 4               False                      False               False
#
#    city_Shen Zhen Shi  city_Shi Jia Zhuang Shi  city_Shi Yan Shi  \
# 0               False                    False             False
# 1               False                    False             False
# 2               False                    False             False
# 3               False                    False             False
# 4               False                    False             False
#
#    city_Shuang Ya Shan Shi  city_Si Ping Shi  city_Song Yuan Shi  \
# 0                    False             False               False
# 1                    False             False               False
# 2                    False             False               False
# 3                    False             False               False
# 4                    False             False               False
#
#    city_Su Zhou Shi  city_Sui Hua Shi  city_Sui Zhou Shi  city_Tai An Shi  \
# 0             False             False              False            False
# 1             False             False              False            False
# 2              True             False              False            False
# 3             False             False              False            False
# 4             False             False              False            False
#
#    city_Tai Yuan Shi  city_Tai Zhou Shi  city_Tang Shan Shi  \
# 0              False              False               False
# 1              False              False               False
# 2              False              False               False
# 3              False              False               False
# 4              False              False               False
#
#    city_Tian Men Shi  city_Tie Ling Shi  city_Tong Hua Shi  \
# 0              False              False              False
# 1              False              False              False
# 2              False              False              False
# 3              False              False              False
# 4              False              False              False
#
#    city_Tong Ling Shi  city_Wan Ning Shi  city_Wei Fang Shi  city_Wei Hai Shi  \
# 0               False              False              False             False
# 1               False              False              False             False
# 2               False              False              False             False
# 3               False              False              False             False
# 4               False              False              False             False
#
#    city_Wei Nan Shi  city_Wen Chang Shi  city_Wen Zhou Shi  city_Wu Han Shi  \
# 0             False               False              False            False
# 1             False               False              False            False
# 2             False               False              False            False
# 3             False               False              False            False
# 4             False               False              False            False
#
#    city_Wu Hu Shi  city_Wu Xi Shi  city_Wu Zhou Shi  city_Xi An Shi  \
# 0           False           False             False           False
# 1           False           False             False           False
# 2           False           False             False           False
# 3           False           False             False           False
# 4           False           False             False           False
#
#    city_Xi Shuang Ban Na Zhou  city_Xia Men Shi  city_Xian Ning Shi  \
# 0                       False             False               False
# 1                       False             False               False
# 2                       False             False               False
# 3                       False             False               False
# 4                       False             False               False
#
#    city_Xian Tao Shi  city_Xian Yang Shi  city_Xiang Tan Shi  \
# 0              False               False               False
# 1              False               False               False
# 2              False               False               False
# 3              False               False               False
# 4              False               False               False
#
#    city_Xiang Xi Zhou  city_Xiang Yang Shi  city_Xiao Gan Shi  \
# 0               False                False              False
# 1               False                False              False
# 2               False                False              False
# 3               False                False              False
# 4               False                False              False
#
#    city_Xin Xiang Shi  city_Xin Yang Shi  city_Xin Yu Shi  city_Xin Zhou Shi  \
# 0               False              False            False              False
# 1               False              False            False              False
# 2               False              False            False              False
# 3               False              False            False              False
# 4               False              False            False              False
#
#    city_Xing Tai Shi  city_Xu Zhou Shi  city_Xuan Cheng Shi  city_Yan An Shi  \
# 0              False             False                False            False
# 1              False             False                False            False
# 2              False             False                False            False
# 3              False             False                False            False
# 4              False             False                False            False
#
#    city_Yan Bian Zhou  city_Yan Cheng Shi  city_Yan Tai Shi  \
# 0               False               False             False
# 1               False               False             False
# 2               False               False             False
# 3               False               False             False
# 4               False               False             False
#
#    city_Yang Zhou Shi  city_Yi Bin Shi  city_Yi Chang Shi  city_Yi Chun Shi  \
# 0               False            False              False             False
# 1               False            False              False             False
# 2               False            False              False             False
# 3               False            False              False             False
# 4               False            False              False             False
#
#    city_Ying Kou Shi  city_Ying Tan Shi  city_Yu Lin Shi  city_Yu Xi Shi  \
# 0              False              False            False           False
# 1              False              False            False           False
# 2              False              False            False           False
# 3              False              False            False           False
# 4              False              False            False           False
#
#    city_Yue Yang Shi  city_Yun Cheng Shi  city_Zao Zhuang Shi  \
# 0              False               False                False
# 1              False               False                False
# 2              False               False                False
# 3              False               False                False
# 4              False               False                False
#
#    city_Zhan Jiang Shi  city_Zhang Jia Jie Shi  city_Zhang Jia Kou Shi  \
# 0                False                   False                   False
# 1                False                   False                   False
# 2                False                   False                   False
# 3                False                   False                   False
# 4                False                   False                   False
#
#    city_Zhang Zhi Shi  city_Zhang Zhou Shi  city_Zhao Qing Shi  \
# 0               False                False               False
# 1               False                False               False
# 2               False                False               False
# 3               False                False               False
# 4               False                False               False
#
#    city_Zhao Yang Shi  city_Zhen Jiang Shi  city_Zheng Zhou Shi  \
# 0               False                False                False
# 1               False                False                False
# 2               False                False                False
# 3               False                False                False
# 4               False                False                False
#
#    city_Zhong Shan Shi  city_Zhou Shan Shi  city_Zhu Hai Shi  \
# 0                False               False             False
# 1                False               False             False
# 2                False               False             False
# 3                False               False             False
# 4                False               False             False
#
#    city_Zhu Ma Dian Shi  city_Zhu Zhou Shi  city_Zi Bo Shi  province_Beijing  \
# 0                 False              False           False             False
# 1                 False              False           False             False
# 2                 False              False           False             False
# 3                 False              False           False             False
# 4                 False              False           False             False
#
#    province_Fujian  province_Guangdong  province_Guangxi  province_Hainan  \
# 0            False               False             False            False
# 1            False               False             False            False
# 2            False               False             False            False
# 3            False               False             False            False
# 4            False               False             False            False
#
#    province_Hebei  province_Heilongjiang  province_Henan  province_Hubei  \
# 0           False                  False           False           False
# 1           False                  False            True           False
# 2           False                  False           False           False
# 3           False                  False           False           False
# 4           False                  False           False           False
#
#    province_Hunan  province_Jiangsu  province_Jiangxi  province_Jilin  \
# 0           False             False             False           False
# 1           False             False             False           False
# 2           False              True             False           False
# 3           False             False             False           False
# 4           False             False              True           False
#
#    province_Liaoning  province_Shaanxi  province_Shandong  province_Shanghai  \
# 0              False             False              False              False
# 1              False             False              False              False
# 2              False             False              False              False
# 3              False             False              False               True
# 4              False             False              False              False
#
#    province_Shanxi  province_Sichuan  province_Yunnan  province_Zhejiang  \
# 0             True             False            False              False
# 1            False             False            False              False
# 2            False             False            False              False
# 3            False             False            False              False
# 4            False             False            False              False
#
#    is_group_tour_Yes  season_Chun Ji  season_Summer  season_Winter  \
# 0              False           False          False           True
# 1              False           False          False          False
# 2              False           False           True          False
# 3              False           False          False          False
# 4              False           False          False           True
#
#    is_holiday_Yes
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False

# %% [markdown]
# ## Model Training

# %%
# Setting for Modeling
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from surprise import SVD, Dataset, Reader
from sklearn.decomposition import TruncatedSVD
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    mean_squared_error,
    mean_absolute_error,
    accuracy_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay
)

RANDOM_SEED = 42
TEST_FRACTION = 0.20
 
SVD_FACTORS = 20
SVD_EPOCHS = 25
 
TOP_K_VALUES = [5, 10]
 
# Rating >= 4 Means the User Liked the Attraction
LIKE_THRESHOLD = 4.0
 
# Hybrid Weights
ALPHA_VALUES = np.arange(0.0, 1.01, 0.10)

# %%
# Data Preparation for Modeling
print("=" * 60)
print("Preparing Data")
print("=" * 60)
 
ratings = df[
    ["tourist_id", "attraction_name", "rating"]
].copy()
 
# Average Duplicate Ratings per Tourist-Item Pair
ratings = (
    ratings
    .groupby(
        ["tourist_id", "attraction_name"],
        as_index=False
    )["rating"]
    .mean()
)
 
# Canonical Mappings 
user_ids = sorted(
    ratings["tourist_id"].unique()
)
 
item_ids = sorted(
    ratings["attraction_name"].unique()
)
 
user_to_idx = {
    user_id: i
    for i, user_id in enumerate(user_ids)
}
 
item_to_idx = {
    item_id: i
    for i, item_id in enumerate(item_ids)
}
 
idx_to_item = {
    i: item
    for item, i in item_to_idx.items()
}
 
ratings["user_idx"] = ratings[
    "tourist_id"
].map(user_to_idx)
 
ratings["item_idx"] = ratings[
    "attraction_name"
].map(item_to_idx)
 
n_users = len(user_ids)
n_items = len(item_ids)
 
density = len(ratings) / (
    n_users * n_items
)
 
print(f"Users:            {n_users:,}")
print(f"Items:            {n_items:,}")
print(f"Interactions:     {len(ratings):,}")
print(f"Matrix density:   {density:.4%}")
print(f"Matrix sparsity:  {1 - density:.4%}")
# Out:
# ============================================================
# Preparing Data
# ============================================================
# Users:            10,000
# Items:            431
# Interactions:     98,858
# Matrix density:   2.2937%
# Matrix sparsity:  97.7063%

# %%
# Train and Test Data Splitting
print("=" * 60)
print("Train and Test Data Splitting")
print("=" * 60)
 
train_rows = []
test_rows = []
 
for uid, group in ratings.groupby("user_idx"):
    n = len(group)
    # Users with Only One Interaction
    # Remain Entirely in Training
    if n < 2:
        train_rows.append(group)
        continue
    # At Least One Test Item
    n_test = max(
        1,
        int(round(n * TEST_FRACTION))
    )
    shuffled = group.sample(
        frac=1.0,
        random_state=RANDOM_SEED
    )
    test_rows.append(
        shuffled.iloc[:n_test]
    )
    train_rows.append(
        shuffled.iloc[n_test:]
    )
 
train_df = pd.concat(
    train_rows,
    ignore_index=True
)
 
test_df = (
    pd.concat(
        test_rows,
        ignore_index=True
    )
    if test_rows
    else pd.DataFrame(
        columns=ratings.columns
    )
)
 
global_mean = train_df["rating"].mean()
print(f"Train: {len(train_df):,}")
print(f"Test:  {len(test_df):,}")
print(f"Global mean rating: {global_mean:.4f}")
# Out:
# ============================================================
# Train and Test Data Splitting
# ============================================================
# Train: 79,101
# Test:  19,757
# Global mean rating: 4.4326

# %% [markdown]
# ## Model 1: SVD COLLABORATIVE FILTERING

# %%
# Model 1:
# SVD COLLABORATIVE FILTERING

print("\n" + "=" * 60)
print("Model 1: SVD COLLABORATIVE FILTERING")
print("=" * 60)

# 3.1 Training SVD Model
print("\nTraining SVD model...")

reader = Reader(rating_scale=(1.0, 5.0))

data = Dataset.load_from_df(
    train_df[["user_idx", "item_idx", "rating"]], reader
)

trainset = data.build_full_trainset()

svd_model = SVD(
    n_factors=SVD_FACTORS, random_state=RANDOM_SEED, n_epochs=SVD_EPOCHS
)

svd_model.fit(trainset)

print(f"CF component ready (Surprise SVD k={SVD_FACTORS})")

# Predict Test Rating
print("\nGenerating SVD predictions for test data...")

svd_test_predictions = []

for row in test_df.itertuples():
    prediction = svd_model.predict(row.user_idx, row.item_idx)
    svd_test_predictions.append(prediction.est)

svd_test_predictions = np.clip(np.array(svd_test_predictions), 1.0, 5.0)

y_true = test_df["rating"].values
y_pred = svd_test_predictions

# Rating Prediction Metrics
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)

# Classification:
# Rating >= 4.0 = Like
# Rating < 4.0 = Not Like

LIKE_THRESHOLD = 4.0

y_true_class = (y_true >= LIKE_THRESHOLD).astype(int)
y_pred_class = (y_pred >= LIKE_THRESHOLD).astype(int)

class_accuracy = accuracy_score(y_true_class, y_pred_class)
class_f1 = f1_score(y_true_class, y_pred_class, zero_division=0)

print("\n" + "-" * 60)
print("SVD Rating Prediction Result")
print("-" * 60)

print(f"RMSE           = {rmse:.4f}")
print(f"MAE            = {mae:.4f}")
print(f"Class Accuracy = {class_accuracy:.4f}")
print(f"Class F1-Score = {class_f1:.4f}")
print("\n")

# Confusion Matrix
cm = confusion_matrix(y_true_class, y_pred_class)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, display_labels=["Not Like", "Like"]
)

fig, ax = plt.subplots(figsize=(6, 5))
disp.plot(ax=ax, values_format="d", colorbar=True, cmap=plt.cm.Blues)

ax.grid(False)
plt.title("SVD: Confusion Matrix", fontsize=12, pad=10)
plt.tight_layout()
plt.show()

print("\n")

# Actual vs Predicted Ratings
plt.figure(figsize=(7, 6))

plt.scatter(y_true, y_pred, alpha=0.25)
plt.plot([1, 5], [1, 5], linestyle="--")

plt.xlabel("Actual Rating")
plt.ylabel("Predicted Rating")
plt.title("SVD: Actual vs Predicted Ratings")

plt.xlim(1, 5)
plt.ylim(1, 5)

plt.tight_layout()
plt.show()

# Create Full User-Item Prediction Matrix
print("\nGenerating full SVD prediction matrix...")

pred_cf_matrix = np.zeros(
    (n_users, n_items)
)

for u in range(n_users):

    for i in range(n_items):

        pred_cf_matrix[u, i] = (
            svd_model
            .predict(u, i)
            .est
        )


pred_cf_matrix = np.clip(
    pred_cf_matrix,
    1.0,
    5.0
)

print(
    "SVD prediction matrix shape:",
    pred_cf_matrix.shape
)


# Top-N Evaluation For SVD Only
TOP_K = 5

print("\n" + "-" * 60)
print(f"SVD TOP-{TOP_K} RECOMMENDATION EVALUATION")
print("-" * 60)

# Items already seen in training
train_items_by_user = (
    train_df.groupby("user_idx")["item_idx"].apply(set).to_dict()
)

# Relevant test items
# Rating >= 4.0
test_relevant_by_user = (
    test_df[test_df["rating"] >= LIKE_THRESHOLD]
    .groupby("user_idx")["item_idx"]
    .apply(set)
    .to_dict()
)

# Evaluation containers
precision_scores = []
recall_scores = []
f1_scores = []
hit_scores = []
ndcg_scores = []
evaluated_users = 0

# Evaluate every user
for user_idx, relevant_items in test_relevant_by_user.items():
    if user_idx not in train_items_by_user:
        continue

    seen_items = train_items_by_user[user_idx]

    # Candidate items = items NOT seen during training
    candidate_items = [i for i in range(n_items) if i not in seen_items]

    if len(candidate_items) == 0:
        continue

    # Rank candidate items using SVD predicted rating
    candidate_scores = [
        (i, pred_cf_matrix[user_idx, i]) for i in candidate_items
    ]

    candidate_scores.sort(key=lambda x: x[1], reverse=True)

    recommended_items = [item for item, score in candidate_scores[:TOP_K]]
    recommended_set = set(recommended_items)
    relevant_set = set(relevant_items)

    # Number of hits
    hits = len(recommended_set.intersection(relevant_set))

    # Precision@K
    precision = hits / TOP_K

    # Recall@K
    recall = hits / len(relevant_set) if len(relevant_set) > 0 else 0

    # F1@K
    if precision + recall > 0:
        f1 = 2 * precision * recall / (precision + recall)
    else:
        f1 = 0

    # Hit Rate@K
    hit = 1 if hits > 0 else 0

    # NDCG@K
    dcg = 0.0

    for rank, item in enumerate(recommended_items, start=1):
        if item in relevant_set:
            dcg += 1 / np.log2(rank + 1)

    ideal_hits = min(len(relevant_set), TOP_K)

    idcg = sum(1 / np.log2(rank + 1) for rank in range(1, ideal_hits + 1))

    ndcg = dcg / idcg if idcg > 0 else 0

    # Store results
    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)
    hit_scores.append(hit)
    ndcg_scores.append(ndcg)

    evaluated_users += 1

# Display Top-N Results
svd_precision = np.mean(precision_scores)
svd_recall = np.mean(recall_scores)
svd_f1 = np.mean(f1_scores)
svd_hr = np.mean(hit_scores)
svd_ndcg = np.mean(ndcg_scores)

print(f"Users evaluated = {evaluated_users}")
print(f"Precision@{TOP_K} = {svd_precision:.4f}")
print(f"Recall@{TOP_K}    = {svd_recall:.4f}")
print(f"F1@{TOP_K}        = {svd_f1:.4f}")
print(f"HR@{TOP_K}        = {svd_hr:.4f}")
print(f"NDCG@{TOP_K}      = {svd_ndcg:.4f}")

# Sample Tourist Recommendation
print("\n" + "=" * 60)
print("Sample Tourist Recommendation")
print("=" * 60)

# Select a representative tourist
user_interaction_counts = train_df.groupby("user_idx").size()

# Select a Tourist with 8-12 Previous Interactions.
eligible_users = user_interaction_counts[
    (user_interaction_counts >= 8) & (user_interaction_counts <= 12)
]

# Randomly Select one Tourist
SAMPLE_USER_IDX = eligible_users.sample(
    1, random_state=RANDOM_SEED
).index[0]

# Convert user_idx Back to original tourist_id
tourist_id = user_ids[SAMPLE_USER_IDX]

print(f"\nTourist ID: {tourist_id}")
print(
    f"Previous interactions: "
    f"{user_interaction_counts[SAMPLE_USER_IDX]}"
)

# Find previous attractions
previous_items = train_df[
    train_df["user_idx"] == SAMPLE_USER_IDX
].sort_values("rating", ascending=False)

print("\nPrevious Attractions")
print("-" * 70)
print(f"{'Attraction':<45}{'Rating':>10}")
print("-" * 70)

for row in previous_items.itertuples():
    attraction_name = idx_to_item[row.item_idx]
    print(f"{attraction_name:<45}{row.rating:>10.2f}")

# Get attractions already visited
seen_items = set(previous_items["item_idx"])

# Generate candidate attractions
candidate_items = [
    item_idx for item_idx in range(n_items) if item_idx not in seen_items
]

# Predict ratings for candidate attractions
recommendation_scores = []

for item_idx in candidate_items:
    predicted_rating = pred_cf_matrix[SAMPLE_USER_IDX, item_idx]
    recommendation_scores.append((item_idx, predicted_rating))

# Sort attractions by predicted rating
recommendation_scores.sort(key=lambda x: x[1], reverse=True)

# Select Top 5 recommendations
top_recommendations = recommendation_scores[:5]

# Display recommendations
print("\nRecommended Attractions")
print("-" * 70)

print(
    f"{'Rank':<8}"
    f"{'Attraction':<45}"
    f"{'Predicted Rating':>17}"
)
print("-" * 70)

for rank, (item_idx, predicted_rating) in enumerate(
    top_recommendations, start=1
):
    attraction_name = idx_to_item[item_idx]

    print(
        f"{rank:<8}"
        f"{attraction_name:<45}"
        f"{predicted_rating:>17.2f}"
    )

# Create a recommendation DataFrame
recommendation_results = []

for rank, (item_idx, predicted_rating) in enumerate(
    top_recommendations, start=1
):
    recommendation_results.append({
        "Tourist ID": tourist_id,
        "Rank": rank,
        "Attraction": idx_to_item[item_idx],
        "Predicted Rating": round(predicted_rating, 2),
    })

recommendation_results_df = pd.DataFrame(recommendation_results)

# Final SVD Model Summary
print("\n" + "=" * 60)
print("SVD FINAL SUMMARY")
print("=" * 60)

print(f"RMSE            : {rmse:.4f}")
print(f"MAE             : {mae:.4f}")
print(f"Classification Accuracy : {class_accuracy:.4f}")
print(f"Classification F1       : {class_f1:.4f}")
print(f"Precision@5     : {svd_precision:.4f}")
print(f"Recall@5        : {svd_recall:.4f}")
print(f"F1@5            : {svd_f1:.4f}")
print(f"HR@5            : {svd_hr:.4f}")
print(f"NDCG@5          : {svd_ndcg:.4f}")
print("=" * 60)
# Out:
# ============================================================
# Model 1: SVD COLLABORATIVE FILTERING
# ============================================================
#
# Training SVD model...
# CF component ready (Surprise SVD k=20)
#
# Generating SVD predictions for test data...
#
# ------------------------------------------------------------
# SVD Rating Prediction Result
# ------------------------------------------------------------
# RMSE           = 0.2872
# MAE            = 0.2449
# Class Accuracy = 0.8955
# Class F1-Score = 0.9436
# Generating full SVD prediction matrix...
# SVD prediction matrix shape: (10000, 431)
#
# ------------------------------------------------------------
# SVD TOP-5 RECOMMENDATION EVALUATION
# ------------------------------------------------------------
# Users evaluated = 9685
# Precision@5 = 0.0045
# Recall@5    = 0.0121
# F1@5        = 0.0064
# HR@5        = 0.0222
# NDCG@5      = 0.0082
#
# ============================================================
# Sample Tourist Recommendation
# ============================================================
#
# Tourist ID: 605
# Previous interactions: 8
#
# Previous Attractions
# ----------------------------------------------------------------------
# Attraction                                       Rating
# ----------------------------------------------------------------------
# Ba Da Ling Chang Cheng                             5.00
# Tian Tai Shan                                      5.00
# Tai Shan                                           5.00
# Mo Gan Shan                                        4.80
# Yue Yang Lou                                       4.50
# Shang Hai Ye Sheng Dong Wu Yuan                    4.20
# Shou Xian Gu Cheng                                 4.10
# Mao Shan                                           4.00
#
# Recommended Attractions
# ----------------------------------------------------------------------
# Rank    Attraction                                    Predicted Rating
# ----------------------------------------------------------------------
# 1       Tian Tang Zhai                                            4.96
# 2       Lao Shan                                                  4.90
# 3       Gui Lin Li Jiang                                          4.89
# 4       Tai Hang Shan Da Xia Gu                                   4.88
# 5       Tian Mu Hu                                                4.88
#
# ============================================================
# SVD FINAL SUMMARY
# ============================================================
# RMSE            : 0.2872
# MAE             : 0.2449
# Classification Accuracy : 0.8955
# Classification F1       : 0.9436
# Precision@5     : 0.0045
# Recall@5        : 0.0121
# F1@5            : 0.0064
# HR@5            : 0.0222
# NDCG@5          : 0.0082
# ============================================================

# %% [markdown]
# ## Model 2: TF-IDF CONTENT-BASED RECOMMENDATION

# %%
# Model 2:
# TF-IDF CONTENT-BASED RECOMMENDATION

print("\n" + "=" * 60)
print("Model 2: TF-IDF CONTENT-BASED RECOMMENDATION")
print("=" * 60)

# Building Attraction Metadata & TF-IDF Features
print("\nBuilding attraction metadata and TF-IDF features...")

def price_tier(price):
    if pd.isna(price):
        return "Unknown"
    elif price <= -1.20:
        # Original price: <= 0
        return "Free"
    elif price <= -0.31:
        # Original price: <= 60
        return "Budget"
    elif price <= 1.03:
        # Original price: <= 150
        return "MidRange"
    else:
        # Original price: > 150
        return "Premium"

attr_meta = (
    df.groupby("attraction_name")
    .agg(
        attraction_category=(
            "attraction_category",
            lambda x: x.mode().iloc[0],
        ),
        attraction_level=(
            "attraction_level",
            lambda x: x.mode().iloc[0],
        ),
        city=("city", lambda x: x.mode().iloc[0]),
        province=("province", lambda x: x.mode().iloc[0]),
        ticket_price=("ticket_price", "mean"),
    )
    .reset_index()
)

attr_meta["price_tier"] = attr_meta["ticket_price"].apply(price_tier)
attr_meta["item_idx"] = attr_meta["attraction_name"].map(item_to_idx)

attr_meta = attr_meta.sort_values("item_idx").reset_index(drop=True)

text_columns = [
    "attraction_category",
    "attraction_level",
    "province",
    "city",
    "price_tier",
]

for col in text_columns:
    attr_meta[col] = (
        attr_meta[col]
        .fillna("Unknown")
        .astype(str)
        .str.replace(" ", "_", regex=False)
    )

# Weighted Metadata Soup (Category = 3x, City = 2x, Others = 1x)
attr_meta["soup"] = (
    (attr_meta["attraction_category"] + " ") * 3
    + (attr_meta["city"] + " ") * 2
    + attr_meta["attraction_level"] + " "
    + attr_meta["province"] + " "
    + attr_meta["price_tier"]
)

vectorizer = TfidfVectorizer(token_pattern=r"[^\s]+")
tfidf_matrix = vectorizer.fit_transform(attr_meta["soup"]).toarray()

print(f"TF-IDF matrix shape: {tfidf_matrix.shape}")

# Building User Content Profiles & Predictions
print("\nBuilding user content profiles and cosine similarity matrix...")

user_profile_matrix = np.zeros((n_users, tfidf_matrix.shape[1]))

for uid, group in train_df.groupby("user_idx"):
    item_indices = group["item_idx"].values
    ratings_weights = group["rating"].values

    user_profile_matrix[uid] = np.average(
        tfidf_matrix[item_indices], axis=0, weights=ratings_weights
    )

content_sim_matrix = cosine_similarity(user_profile_matrix, tfidf_matrix)

# User mean ratings for scaling continuous predictions
user_sums = np.zeros(n_users)
user_counts = np.zeros(n_users)

for uid, group in train_df.groupby("user_idx"):
    user_sums[uid] = group["rating"].sum()
    user_counts[uid] = len(group)

user_means = np.divide(
    user_sums,
    user_counts,
    out=np.full(n_users, global_mean),
    where=user_counts > 0,
)

pred_content_matrix = user_means[:, None] + (
    content_sim_matrix - content_sim_matrix.mean(axis=1, keepdims=True)
) * 1.5

pred_content_matrix = np.clip(pred_content_matrix, 1.0, 5.0)

print("Content-based component ready")

# Predict Test Rating
print("\nGenerating TF-IDF content predictions for test data...")

content_test_predictions = []

for row in test_df.itertuples():
    pred_val = pred_content_matrix[row.user_idx, row.item_idx]
    content_test_predictions.append(pred_val)

content_test_predictions = np.clip(
    np.array(content_test_predictions), 1.0, 5.0
)

y_true = test_df["rating"].values
y_pred = content_test_predictions

# Rating Prediction Metrics
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)

# Classification (Rating >= 4.0 = Like, Rating < 4.0 = Not Like)
LIKE_THRESHOLD = 4.0

y_true_class = (y_true >= LIKE_THRESHOLD).astype(int)
y_pred_class = (y_pred >= LIKE_THRESHOLD).astype(int)

class_accuracy = accuracy_score(y_true_class, y_pred_class)
class_f1 = f1_score(y_true_class, y_pred_class, zero_division=0)

print("\n" + "-" * 60)
print("TF-IDF Content Rating Prediction Result")
print("-" * 60)
print(f"RMSE           = {rmse:.4f}")
print(f"MAE            = {mae:.4f}")
print(f"Class Accuracy = {class_accuracy:.4f}")
print(f"Class F1-Score = {class_f1:.4f}")
print("\n")

# Confusion Matrix 
cm = confusion_matrix(y_true_class, y_pred_class)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, display_labels=["Not Like", "Like"]
)

fig, ax = plt.subplots(figsize=(6, 5))
disp.plot(
    ax=ax, values_format="d", colorbar=True, cmap=plt.cm.Blues
)

ax.grid(False)
plt.title("TF-IDF: Confusion Matrix", fontsize=12, pad=10)
plt.tight_layout()
plt.show()

print("\n")

# Actual vs Predicted Ratings Scatter Plot
plt.figure(figsize=(7, 6))
plt.scatter(y_true, y_pred, alpha=0.25, color="#1f77b4")
plt.plot([1, 5], [1, 5], linestyle="--", color="red")
plt.xlabel("Actual Rating")
plt.ylabel("Predicted Rating")
plt.title("TF-IDF Content: Actual vs Predicted Ratings")
plt.xlim(1, 5)
plt.ylim(1, 5)
plt.tight_layout()
plt.show()

# Top-N Evaluation For TF-IDF Content Only
TOP_K = 5

print("\n" + "-" * 60)
print(f"TF-IDF CONTENT TOP-{TOP_K} RECOMMENDATION EVALUATION")
print("-" * 60)

# Items already seen in training
train_items_by_user = (
    train_df.groupby("user_idx")["item_idx"].apply(set).to_dict()
)

# Relevant test items (Rating >= 4.0)
test_relevant_by_user = (
    test_df[test_df["rating"] >= LIKE_THRESHOLD]
    .groupby("user_idx")["item_idx"]
    .apply(set)
    .to_dict()
)

# Evaluation containers
precision_scores = []
recall_scores = []
f1_scores = []
hit_scores = []
ndcg_scores = []
evaluated_users = 0

# Evaluate every user
for user_idx, relevant_items in test_relevant_by_user.items():

    if user_idx not in train_items_by_user:
        continue

    seen_items = train_items_by_user[user_idx]

    # Candidate items = items NOT seen during training
    candidate_items = [i for i in range(n_items) if i not in seen_items]

    if len(candidate_items) == 0:
        continue

    # Rank candidate items using TF-IDF predicted rating
    candidate_scores = [
        (i, pred_content_matrix[user_idx, i]) for i in candidate_items
    ]

    candidate_scores.sort(key=lambda x: x[1], reverse=True)

    recommended_items = [
        item for item, score in candidate_scores[:TOP_K]
    ]

    recommended_set = set(recommended_items)
    relevant_set = set(relevant_items)

    # Number of hits
    hits = len(recommended_set.intersection(relevant_set))

    # Precision@K
    precision = hits / TOP_K

    # Recall@K
    recall = hits / len(relevant_set) if len(relevant_set) > 0 else 0

    # F1@K
    if precision + recall > 0:
        f1 = 2 * precision * recall / (precision + recall)
    else:
        f1 = 0

    # Hit Rate@K
    hit = 1 if hits > 0 else 0

    # NDCG@K
    dcg = 0.0
    for rank, item in enumerate(recommended_items, start=1):
        if item in relevant_set:
            dcg += 1 / np.log2(rank + 1)

    ideal_hits = min(len(relevant_set), TOP_K)
    idcg = sum(1 / np.log2(rank + 1) for rank in range(1, ideal_hits + 1))

    ndcg = dcg / idcg if idcg > 0 else 0

    # Store results
    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)
    hit_scores.append(hit)
    ndcg_scores.append(ndcg)

    evaluated_users += 1

# Display Top-N Results
content_precision = np.mean(precision_scores)
content_recall = np.mean(recall_scores)
content_f1 = np.mean(f1_scores)
content_hr = np.mean(hit_scores)
content_ndcg = np.mean(ndcg_scores)

print(f"Users evaluated = {evaluated_users}")
print(f"Precision@{TOP_K} = {content_precision:.4f}")
print(f"Recall@{TOP_K}    = {content_recall:.4f}")
print(f"F1@{TOP_K}        = {content_f1:.4f}")
print(f"HR@{TOP_K}        = {content_hr:.4f}")
print(f"NDCG@{TOP_K}      = {content_ndcg:.4f}")

# Sample Tourist Recommendation
print("\n" + "=" * 60)
print("Sample Tourist Recommendation")
print("=" * 60)

# Select a representative tourist
user_interaction_counts = train_df.groupby("user_idx").size()

# Select a Tourist with 8-12 Previous Interactions.
eligible_users = user_interaction_counts[
    (user_interaction_counts >= 8) & (user_interaction_counts <= 12)
]

# Randomly Select one Tourist
SAMPLE_USER_IDX = eligible_users.sample(
    1, random_state=RANDOM_SEED
).index[0]

# Convert user_idx Back to original tourist_id
tourist_id = user_ids[SAMPLE_USER_IDX]

print(f"\nTourist ID: {tourist_id}")
print(
    f"Previous interactions: {user_interaction_counts[SAMPLE_USER_IDX]}"
)

# Find Previous Attractions
previous_items = train_df[
    train_df["user_idx"] == SAMPLE_USER_IDX
].sort_values("rating", ascending=False)

print("\nPrevious Attractions")
print("-" * 70)
print(f"{'Attraction':<45}{'Rating':>10}")
print("-" * 70)

for row in previous_items.itertuples():
    attraction_name = idx_to_item[row.item_idx]
    print(f"{attraction_name:<45}{row.rating:>10.2f}")

# Get Attractions Already Visited
seen_items = set(previous_items["item_idx"])

# Generate Candidate Attractions
candidate_items = [
    item_idx for item_idx in range(n_items) if item_idx not in seen_items
]

# Predict Ratings for Candidate Attractions
recommendation_scores = []

for item_idx in candidate_items:
    predicted_rating = pred_content_matrix[SAMPLE_USER_IDX, item_idx]
    recommendation_scores.append((item_idx, predicted_rating))

# Sort Attractions by Predicted Rating
recommendation_scores.sort(key=lambda x: x[1], reverse=True)

# Select Top 5 Recommendations
top_recommendations = recommendation_scores[:5]

# Display Recommendations
print("\nRecommended Attractions")
print("-" * 70)
print(
    f"{'Rank':<8}{'Attraction':<45}{'Predicted Rating':>17}"
)
print("-" * 70)

for rank, (item_idx, predicted_rating) in enumerate(
    top_recommendations, start=1
):
    attraction_name = idx_to_item[item_idx]
    print(
        f"{rank:<8}{attraction_name:<45}{predicted_rating:>17.2f}"
    )

# Create a Recommendation DataFrame
recommendation_results = []

for rank, (item_idx, predicted_rating) in enumerate(
    top_recommendations, start=1
):
    recommendation_results.append(
        {
            "Tourist ID": tourist_id,
            "Rank": rank,
            "Attraction": idx_to_item[item_idx],
            "Predicted Rating": round(predicted_rating, 2),
        }
    )
recommendation_results_df = pd.DataFrame(recommendation_results)

# Final TF-IDF Model Summary
print("\n" + "=" * 60)
print("TF-IDF FINAL SUMMARY")
print("=" * 60)
print(f"RMSE                    : {rmse:.4f}")
print(f"MAE                     : {mae:.4f}")
print(f"Classification Accuracy : {class_accuracy:.4f}")
print(f"Classification F1       : {class_f1:.4f}")
print(f"Precision@5             : {content_precision:.4f}")
print(f"Recall@5                : {content_recall:.4f}")
print(f"F1@5                    : {content_f1:.4f}")
print(f"HR@5                    : {content_hr:.4f}")
print(f"NDCG@5                  : {content_ndcg:.4f}")
print("=" * 60)
# Out:
# ============================================================
# Model 2: TF-IDF CONTENT-BASED RECOMMENDATION
# ============================================================
#
# Building attraction metadata and TF-IDF features...
# TF-IDF matrix shape: (431, 268)
#
# Building user content profiles and cosine similarity matrix...
# Content-based component ready
#
# Generating TF-IDF content predictions for test data...
#
# ------------------------------------------------------------
# TF-IDF Content Rating Prediction Result
# ------------------------------------------------------------
# RMSE           = 0.3939
# MAE            = 0.3212
# Class Accuracy = 0.8895
# Class F1-Score = 0.9415
# ------------------------------------------------------------
# TF-IDF CONTENT TOP-5 RECOMMENDATION EVALUATION
# ------------------------------------------------------------
# Users evaluated = 9685
# Precision@5 = 0.0044
# Recall@5    = 0.0120
# F1@5        = 0.0062
# HR@5        = 0.0219
# NDCG@5      = 0.0083
#
# ============================================================
# Sample Tourist Recommendation
# ============================================================
#
# Tourist ID: 605
# Previous interactions: 8
#
# Previous Attractions
# ----------------------------------------------------------------------
# Attraction                                       Rating
# ----------------------------------------------------------------------
# Ba Da Ling Chang Cheng                             5.00
# Tian Tai Shan                                      5.00
# Tai Shan                                           5.00
# Mo Gan Shan                                        4.80
# Yue Yang Lou                                       4.50
# Shang Hai Ye Sheng Dong Wu Yuan                    4.20
# Shou Xian Gu Cheng                                 4.10
# Mao Shan                                           4.00
#
# Recommended Attractions
# ----------------------------------------------------------------------
# Rank    Attraction                                    Predicted Rating
# ----------------------------------------------------------------------
# 1       Gu Gong Bo Wu Yuan                                        5.00
# 2       Mu Tian Yu Chang Cheng                                    5.00
# 3       Nan Luo Gu Xiang                                          5.00
# 4       Tian Tan Gong Yuan                                        5.00
# 5       Yi He Yuan                                                5.00
#
# ============================================================
# TF-IDF FINAL SUMMARY
# ============================================================
# RMSE                    : 0.3939
# MAE                     : 0.3212
# Classification Accuracy : 0.8895
# Classification F1       : 0.9415
# Precision@5             : 0.0044
# Recall@5                : 0.0120
# F1@5                    : 0.0062
# HR@5                    : 0.0219
# NDCG@5                  : 0.0083
# ============================================================

# %% [markdown]
# ## Model 3: NEURAL NETWORK (MLP + EMBEDDINGS)

# %%
# Model 3:
# NEURAL NETWORK (MLP + EMBEDDINGS)

print("\n" + "=" * 60)
print("Model 3: NEURAL NETWORK (MLP + EMBEDDINGS)")
print("=" * 60)

# Training MLP Model & Feature Preparation
print("\nTraining MLP model on latent factors and biases...")

# Item mean ratings as bias feature
item_sums_nn = np.zeros(n_items)
item_counts_nn = np.zeros(n_items)

for iid, group in train_df.groupby("item_idx"):
    item_sums_nn[iid] = group["rating"].sum()
    item_counts_nn[iid] = len(group)

item_means_nn = np.divide(
    item_sums_nn,
    item_counts_nn,
    out=np.full(n_items, global_mean),
    where=item_counts_nn > 0,
)

# Extract CF latent factors directly from trained Surprise SVD model
user_cf_embed = np.zeros((n_users, SVD_FACTORS))
item_cf_embed = np.zeros((n_items, SVD_FACTORS))

for uid in range(n_users):
    try:
        inner_uid = trainset.to_inner_uid(uid)
        user_cf_embed[uid] = svd_model.pu[inner_uid]
    except ValueError:
        pass  # leave as zeros for cold-start user

for iid in range(n_items):
    try:
        inner_iid = trainset.to_inner_iid(iid)
        item_cf_embed[iid] = svd_model.qi[inner_iid]
    except ValueError:
        pass  # leave as zeros for cold-start item

# Reduce TF-IDF item vectors to a small dense content embedding
CONTENT_EMBED_DIM = 10

content_svd = TruncatedSVD(
    n_components=CONTENT_EMBED_DIM, random_state=RANDOM_SEED
)

item_content_embed = content_svd.fit_transform(tfidf_matrix)

print("\nExtracting Demographic and Item features from df_final...")

# Identify static User Features (Age, Gender, Source Province, Age Group)
user_cols = ['age'] + [col for col in df_final.columns if col.startswith(('gender_', 'age_group_', 'source_province_'))]

# Identify static Item Features (Price, Level, City, Province)
item_cols = ['ticket_price', 'attraction_level'] + [col for col in df_final.columns if col.startswith(('city_', 'province_'))]

# Static User Features from df_final (we still have tourist_id here)
user_cols = ['age'] + [col for col in df_final.columns if col.startswith(('gender_', 'age_group_', 'source_province_'))]
user_profiles = df_final.groupby('tourist_id')[user_cols].first()

user_feature_matrix = np.zeros((n_users, len(user_cols)))
for raw_id, row in user_profiles.iterrows():
    if raw_id in user_to_idx:
        user_feature_matrix[user_to_idx[raw_id]] = row.values

# Static Item Features using your existing 'attr_meta' dataframe from Model 2!
# Make sure item_cols match the numeric/one-hot columns inside attr_meta
# 2. Static Item Features: Select ONLY numeric or boolean columns from attr_meta (Excludes text strings like 'attraction_level')
item_cols = ['ticket_price'] + [col for col in attr_meta.columns if col.startswith(('city_', 'province_', 'price_tier_'))]

item_feature_matrix = np.zeros((n_items, len(item_cols)))
for idx, row in attr_meta.iterrows():
    i_idx = row['item_idx'] 
    if i_idx < n_items:
        # Convert values explicitly to float to prevent any text conversion issues
        item_feature_matrix[int(i_idx)] = row[item_cols].astype(float).values

print(f"Successfully built User Feature Matrix: {user_feature_matrix.shape}")
print(f"Successfully built Item Feature Matrix: {item_feature_matrix.shape}")

# Build (user, item) -> feature vector function WITH DEMOGRAPHICS
def build_nn_features(user_idx_arr, item_idx_arr):
    # 1. Collaborative & Content Embeddings
    uf = user_cf_embed[user_idx_arr]
    itf = item_cf_embed[item_idx_arr]
    icf = item_content_embed[item_idx_arr]

    # Biases
    ub = (user_means[user_idx_arr] - global_mean).reshape(-1, 1)
    ib = (item_means_nn[item_idx_arr] - global_mean).reshape(-1, 1)

    # NEW: Demographic & Item Metadata
    u_demo = user_feature_matrix[user_idx_arr]
    i_meta = item_feature_matrix[item_idx_arr]

    # Combine them all together!
    return np.hstack([uf, itf, icf, ub, ib, u_demo, i_meta])


X_train_nn = build_nn_features(
    train_df["user_idx"].values, train_df["item_idx"].values
)

y_train_nn = train_df["rating"].values

nn_scaler = StandardScaler()
X_train_nn_scaled = nn_scaler.fit_transform(X_train_nn)

mlp_model = MLPRegressor(
    hidden_layer_sizes=(64, 32),
    activation="relu",
    solver="adam",
    alpha=1e-3,
    learning_rate_init=1e-3,
    max_iter=300,
    early_stopping=True,
    n_iter_no_change=15,
    random_state=RANDOM_SEED,
)

mlp_model.fit(X_train_nn_scaled, y_train_nn)

print(
    f"MLP trained: {mlp_model.hidden_layer_sizes} hidden layers, "
    f"{mlp_model.n_iter_} iterations, "
    f"final training loss: {mlp_model.loss_:.4f}"
)

# Predict full user x item matrix in batches for top-N ranking
pred_nn_matrix = np.zeros((n_users, n_items), dtype=np.float32)
all_items_arr = np.arange(n_items)
NN_BATCH_SIZE = 500

for start in range(0, n_users, NN_BATCH_SIZE):
    end = min(start + NN_BATCH_SIZE, n_users)
    batch_users = np.arange(start, end)

    u_grid = np.repeat(batch_users, n_items)
    i_grid = np.tile(all_items_arr, len(batch_users))

    X_batch = build_nn_features(u_grid, i_grid)
    X_batch_scaled = nn_scaler.transform(X_batch)

    preds = mlp_model.predict(X_batch_scaled)
    pred_nn_matrix[start:end] = preds.reshape(len(batch_users), n_items)

pred_nn_matrix = np.clip(pred_nn_matrix, 1.0, 5.0)

print("Neural network component ready")

# Predict Test Rating
print("\nGenerating MLP predictions for test data...")

mlp_test_predictions = []

for row in test_df.itertuples():
    pred_val = pred_nn_matrix[row.user_idx, row.item_idx]
    mlp_test_predictions.append(pred_val)

mlp_test_predictions = np.clip(
    np.array(mlp_test_predictions), 1.0, 5.0
)

y_true = test_df["rating"].values
y_pred = mlp_test_predictions

# Rating Prediction Metrics
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)

# Classification (Rating >= 4.0 = Like, Rating < 4.0 = Not Like)
LIKE_THRESHOLD = 4.0

y_true_class = (y_true >= LIKE_THRESHOLD).astype(int)
y_pred_class = (y_pred >= LIKE_THRESHOLD).astype(int)

class_accuracy = accuracy_score(y_true_class, y_pred_class)
class_f1 = f1_score(y_true_class, y_pred_class, zero_division=0)

print("\n" + "-" * 60)
print("MLP Rating Prediction Result")
print("-" * 60)
print(f"RMSE           = {rmse:.4f}")
print(f"MAE            = {mae:.4f}")
print(f"Class Accuracy = {class_accuracy:.4f}")
print(f"Class F1-Score = {class_f1:.4f}")
print("\n")

# Confusion Matrix 
cm = confusion_matrix(y_true_class, y_pred_class)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, display_labels=["Not Like", "Like"]
)

fig, ax = plt.subplots(figsize=(6, 5))
disp.plot(
    ax=ax, values_format="d", colorbar=True, cmap=plt.cm.Blues
)

ax.grid(False)
plt.title("MLP: Confusion Matrix", fontsize=12, pad=10)
plt.tight_layout()
plt.show()

print("\n")

# Actual vs Predicted Ratings Scatter Plot
plt.figure(figsize=(7, 6))
plt.scatter(y_true, y_pred, alpha=0.25, color="#1f77b4")
plt.plot([1, 5], [1, 5], linestyle="--", color="red")
plt.xlabel("Actual Rating")
plt.ylabel("Predicted Rating")
plt.title("MLP Neural Network: Actual vs Predicted Ratings")
plt.xlim(1, 5)
plt.ylim(1, 5)
plt.tight_layout()
plt.show()

# Top-N Evaluation For MLP Only
TOP_K = 5

print("\n" + "-" * 60)
print(f"MLP TOP-{TOP_K} RECOMMENDATION EVALUATION")
print("-" * 60)

# Items already seen in training
train_items_by_user = (
    train_df.groupby("user_idx")["item_idx"].apply(set).to_dict()
)

# Relevant test items (Rating >= 4.0)
test_relevant_by_user = (
    test_df[test_df["rating"] >= LIKE_THRESHOLD]
    .groupby("user_idx")["item_idx"]
    .apply(set)
    .to_dict()
)

# Evaluation containers
precision_scores = []
recall_scores = []
f1_scores = []
hit_scores = []
ndcg_scores = []
evaluated_users = 0

# Evaluate every user
for user_idx, relevant_items in test_relevant_by_user.items():

    if user_idx not in train_items_by_user:
        continue

    seen_items = train_items_by_user[user_idx]

    # Candidate items = items NOT seen during training
    candidate_items = [i for i in range(n_items) if i not in seen_items]

    if len(candidate_items) == 0:
        continue

    # Rank candidate items using MLP predicted rating
    candidate_scores = [
        (i, pred_nn_matrix[user_idx, i]) for i in candidate_items
    ]

    candidate_scores.sort(key=lambda x: x[1], reverse=True)

    recommended_items = [
        item for item, score in candidate_scores[:TOP_K]
    ]

    recommended_set = set(recommended_items)
    relevant_set = set(relevant_items)

    # Number of hits
    hits = len(recommended_set.intersection(relevant_set))

    # Precision@K
    precision = hits / TOP_K

    # Recall@K
    recall = hits / len(relevant_set) if len(relevant_set) > 0 else 0

    # F1@K
    if precision + recall > 0:
        f1 = 2 * precision * recall / (precision + recall)
    else:
        f1 = 0

    # Hit Rate@K
    hit = 1 if hits > 0 else 0

    # NDCG@K
    dcg = 0.0
    for rank, item in enumerate(recommended_items, start=1):
        if item in relevant_set:
            dcg += 1 / np.log2(rank + 1)

    ideal_hits = min(len(relevant_set), TOP_K)
    idcg = sum(1 / np.log2(rank + 1) for rank in range(1, ideal_hits + 1))

    ndcg = dcg / idcg if idcg > 0 else 0

    # Store results
    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)
    hit_scores.append(hit)
    ndcg_scores.append(ndcg)

    evaluated_users += 1

# Display Top-N Results
mlp_precision = np.mean(precision_scores)
mlp_recall = np.mean(recall_scores)
mlp_f1 = np.mean(f1_scores)
mlp_hr = np.mean(hit_scores)
mlp_ndcg = np.mean(ndcg_scores)

print(f"Users evaluated = {evaluated_users}")
print(f"Precision@{TOP_K} = {mlp_precision:.4f}")
print(f"Recall@{TOP_K}    = {mlp_recall:.4f}")
print(f"F1@{TOP_K}        = {mlp_f1:.4f}")
print(f"HR@{TOP_K}        = {mlp_hr:.4f}")
print(f"NDCG@{TOP_K}      = {mlp_ndcg:.4f}")

# Sample Tourist Recommendation
print("\n" + "=" * 60)
print("Sample Tourist Recommendation")
print("=" * 60)

# Select a representative tourist
user_interaction_counts = train_df.groupby("user_idx").size()

# Select a Tourist with 8-12 Previous Interactions.
eligible_users = user_interaction_counts[
    (user_interaction_counts >= 8) & (user_interaction_counts <= 12)
]

# Randomly Select one Tourist
SAMPLE_USER_IDX = eligible_users.sample(
    1, random_state=RANDOM_SEED
).index[0]

# Convert user_idx Back to original tourist_id
tourist_id = user_ids[SAMPLE_USER_IDX]

print(f"\nTourist ID: {tourist_id}")
print(
    f"Previous interactions: {user_interaction_counts[SAMPLE_USER_IDX]}"
)

# Find previous attractions
previous_items = train_df[
    train_df["user_idx"] == SAMPLE_USER_IDX
].sort_values("rating", ascending=False)

print("\nPrevious Attractions")
print("-" * 70)
print(f"{'Attraction':<45}{'Rating':>10}")
print("-" * 70)

for row in previous_items.itertuples():
    attraction_name = idx_to_item[row.item_idx]
    print(f"{attraction_name:<45}{row.rating:>10.2f}")

# Get attractions already visited
seen_items = set(previous_items["item_idx"])

# Generate candidate attractions
candidate_items = [
    item_idx for item_idx in range(n_items) if item_idx not in seen_items
]

# Predict ratings for candidate attractions
recommendation_scores = []

for item_idx in candidate_items:
    predicted_rating = pred_nn_matrix[SAMPLE_USER_IDX, item_idx]
    recommendation_scores.append((item_idx, predicted_rating))

# Sort attractions by predicted rating
recommendation_scores.sort(key=lambda x: x[1], reverse=True)

# Select Top 5 recommendations
top_recommendations = recommendation_scores[:5]

# Display recommendations
print("\nRecommended Attractions")
print("-" * 70)
print(
    f"{'Rank':<8}{'Attraction':<45}{'Predicted Rating':>17}"
)
print("-" * 70)

for rank, (item_idx, predicted_rating) in enumerate(
    top_recommendations, start=1
):
    attraction_name = idx_to_item[item_idx]
    print(
        f"{rank:<8}{attraction_name:<45}{predicted_rating:>17.2f}"
    )

# Create a recommendation DataFrame
recommendation_results = []

for rank, (item_idx, predicted_rating) in enumerate(
    top_recommendations, start=1
):
    recommendation_results.append(
        {
            "Tourist ID": tourist_id,
            "Rank": rank,
            "Attraction": idx_to_item[item_idx],
            "Predicted Rating": round(predicted_rating, 2),
        }
    )

recommendation_results_df = pd.DataFrame(recommendation_results)

# Final MLP Model Summary
print("\n" + "=" * 60)
print("MLP FINAL SUMMARY")
print("=" * 60)
print(f"RMSE                    : {rmse:.4f}")
print(f"MAE                     : {mae:.4f}")
print(f"Classification Accuracy : {class_accuracy:.4f}")
print(f"Classification F1       : {class_f1:.4f}")
print(f"Precision@5             : {mlp_precision:.4f}")
print(f"Recall@5                : {mlp_recall:.4f}")
print(f"F1@5                    : {mlp_f1:.4f}")
print(f"HR@5                    : {mlp_hr:.4f}")
print(f"NDCG@5                  : {mlp_ndcg:.4f}")
print("=" * 60)
# Out:
# ============================================================
# Model 3: NEURAL NETWORK (MLP + EMBEDDINGS)
# ============================================================
#
# Training MLP model on latent factors and biases...
#
# Extracting Demographic and Item features from df_final...
# Successfully built User Feature Matrix: (10000, 39)
# Successfully built Item Feature Matrix: (431, 1)
# MLP trained: (64, 32) hidden layers, 46 iterations, final training loss: 0.0333
# Neural network component ready
#
# Generating MLP predictions for test data...
#
# ------------------------------------------------------------
# MLP Rating Prediction Result
# ------------------------------------------------------------
# RMSE           = 0.3090
# MAE            = 0.2587
# Class Accuracy = 0.8895
# Class F1-Score = 0.9400
# ------------------------------------------------------------
# MLP TOP-5 RECOMMENDATION EVALUATION
# ------------------------------------------------------------
# Users evaluated = 9685
# Precision@5 = 0.0054
# Recall@5    = 0.0143
# F1@5        = 0.0077
# HR@5        = 0.0268
# NDCG@5      = 0.0101
#
# ============================================================
# Sample Tourist Recommendation
# ============================================================
#
# Tourist ID: 605
# Previous interactions: 8
#
# Previous Attractions
# ----------------------------------------------------------------------
# Attraction                                       Rating
# ----------------------------------------------------------------------
# Ba Da Ling Chang Cheng                             5.00
# Tian Tai Shan                                      5.00
# Tai Shan                                           5.00
# Mo Gan Shan                                        4.80
# Yue Yang Lou                                       4.50
# Shang Hai Ye Sheng Dong Wu Yuan                    4.20
# Shou Xian Gu Cheng                                 4.10
# Mao Shan                                           4.00
#
# Recommended Attractions
# ----------------------------------------------------------------------
# Rank    Attraction                                    Predicted Rating
# ----------------------------------------------------------------------
# 1       Sha Jia Bang                                              5.00
# 2       Li Jiang Gu Cheng                                         5.00
# 3       Qing Yuan Shan                                            5.00
# 4       Tian Tang Zhai                                            4.97
# 5       Shao Shan                                                 4.94
#
# ============================================================
# MLP FINAL SUMMARY
# ============================================================
# RMSE                    : 0.3090
# MAE                     : 0.2587
# Classification Accuracy : 0.8895
# Classification F1       : 0.9400
# Precision@5             : 0.0054
# Recall@5                : 0.0143
# F1@5                    : 0.0077
# HR@5                    : 0.0268
# NDCG@5                  : 0.0101
# ============================================================

# %% [markdown]
# ## Preparation for Hybrid Model

# %%
# NORMALIZE COMPONENT SCORES
print("\n" + "=" * 60)
print("NORMALIZING COMPONENT SCORES")
print("=" * 60)
 
def minmax_normalize(matrix):
    min_vals = matrix.min(
        axis=1,
        keepdims=True
    )
    max_vals = matrix.max(
        axis=1,
        keepdims=True
    )
    denom = (
        max_vals - min_vals
    )
    denom[
        denom == 0
    ] = 1.0
    return (
        matrix - min_vals
    ) / denom

# Normalize CF scores
cf_norm = minmax_normalize(
    pred_cf_matrix
)
 
# Normalize content similarity
content_norm = minmax_normalize(
    content_sim_matrix
)
 
# Normalize the neural network scores 
nn_norm = minmax_normalize(
    pred_nn_matrix
)

print(
    f"CF normalized range:      "
    f"{cf_norm.min():.4f} - "
    f"{cf_norm.max():.4f}"
)
 
print(
    f"Content normalized range: "
    f"{content_norm.min():.4f} - "
    f"{content_norm.max():.4f}"
)
 
print(
    f"NN normalized range:      "
    f"{nn_norm.min():.4f} - "
    f"{nn_norm.max():.4f}"
)
# Out:
# ============================================================
# NORMALIZING COMPONENT SCORES
# ============================================================
# CF normalized range:      0.0000 - 1.0000
# Content normalized range: 0.0000 - 1.0000
# NN normalized range:      0.0000 - 1.0000

# %%
# TOP-N EVALUATION SETUP
print("\n" + "=" * 60)
print("TOP-N EVALUATION SETUP")
print("=" * 60)

# Items already seen during training
# These items should not be recommended again.
train_seen = train_df.groupby("user_idx")["item_idx"].apply(set).to_dict()

# Define relevant items
# An item is relevant if:
# Actual test rating >= 4.0
# 5 = Relevant
# 4 = Relevant
# 3 = Not Relevant
# 2 = Not Relevant
# 1 = Not Relevant
test_relevant = {}

for uid, group in test_df.groupby("user_idx"):
    relevant_items = group.loc[
        group["rating"] >= LIKE_THRESHOLD, "item_idx"
    ].tolist()

    test_relevant[uid] = set(relevant_items)

# Evaluation statistics
users_with_relevant_items = sum(
    len(items) > 0 for items in test_relevant.values()
)

total_relevant_items = sum(
    len(items) for items in test_relevant.values()
)

print(f"Like threshold:            {LIKE_THRESHOLD:.1f}")
print(f"Users with relevant items: {users_with_relevant_items:,}")
print(f"Total relevant test items: {total_relevant_items:,}")

# METRIC FUNCTIONS
def precision_at_k(recommended, relevant, k):
    recommended = recommended[:k]

    if len(recommended) == 0:
        return 0.0

    hits = len(set(recommended) & set(relevant))

    return hits / k

def recall_at_k(recommended, relevant, k):
    if len(relevant) == 0:
        return 0.0

    recommended = recommended[:k]

    hits = len(set(recommended) & set(relevant))

    return hits / len(relevant)

def f1_score_at_k(precision, recall):
    if (precision + recall) == 0:
        return 0.0

    return 2 * precision * recall / (precision + recall)

def hit_rate_at_k(recommended, relevant, k):
    recommended = recommended[:k]

    hits = len(set(recommended) & set(relevant))

    return 1.0 if hits > 0 else 0.0

def ndcg_at_k(recommended, relevant, k):
    recommended = recommended[:k]
    dcg = 0.0

    for rank, item in enumerate(recommended, start=1):
        if item in relevant:
            dcg += 1 / np.log2(rank + 1)

    ideal_hits = min(len(relevant), k)

    if ideal_hits == 0:
        return 0.0

    idcg = sum(1 / np.log2(rank + 1) for rank in range(1, ideal_hits + 1))

    return dcg / idcg

# EVALUATION ENGINE
def evaluate_ranking(score_matrix=None, score_vector=None):
    results = {
        k: {
            "Precision": [],
            "Recall": [],
            "F1": [],
            "HitRate": [],
            "NDCG": [],
        }
        for k in TOP_K_VALUES
    }

    # Evaluate each user
    for uid, relevant in test_relevant.items():
        # Skip users with no liked items in the test set
        if len(relevant) == 0:
            continue
        # Get scores
        if score_matrix is not None:
            user_scores = score_matrix[uid].copy()

        elif score_vector is not None:
            user_scores = score_vector.copy()

        else:
            raise ValueError(
                "Either score_matrix or score_vector must be provided."
            )

        # Remove training items-
        seen = train_seen.get(uid, set())

        if len(seen) > 0:
            user_scores[list(seen)] = -np.inf

        # Rank attractions
        ranked_items = np.argsort(user_scores)[::-1]

        # Calculate metrics
        for k in TOP_K_VALUES:
            precision = precision_at_k(ranked_items, relevant, k)
            recall = recall_at_k(ranked_items, relevant, k)
            f1 = f1_score_at_k(precision, recall)
            hit_rate = hit_rate_at_k(ranked_items, relevant, k)
            ndcg = ndcg_at_k(ranked_items, relevant, k)

            results[k]["Precision"].append(precision)
            results[k]["Recall"].append(recall)
            results[k]["F1"].append(f1)
            results[k]["HitRate"].append(hit_rate)
            results[k]["NDCG"].append(ndcg)
            
    # Average metrics across users
    summary = {}

    for k in TOP_K_VALUES:
        summary[k] = {}

        for metric, values in results[k].items():
            if len(values) > 0:
                summary[k][metric] = np.mean(values)
            else:
                summary[k][metric] = 0.0

    return summary
# Out:
# ============================================================
# TOP-N EVALUATION SETUP
# ============================================================
# Like threshold:            4.0
# Users with relevant items: 9,685
# Total relevant test items: 17,703

# %% [markdown]
# ## Model 4: HYBRID WEIGHT TUNING (CF + TF-IDF CONTENT)

# %%
# Model 4:
# HYBRID WEIGHT TUNING (CF + TF-IDF CONTENT)

print("\n" + "=" * 60)
print("TUNING HYBRID WEIGHT")
print("=" * 60)

#Grid Search over Alpha Values
print("\nEvaluating hybrid model performance across alpha values...")

alpha_results = []

for alpha in ALPHA_VALUES:

    # Hybrid score
    # alpha = CF weight
    # 1-alpha = Content weight
    hybrid_scores = (
        alpha * cf_norm
        + (1 - alpha) * content_norm
    )

    metrics = evaluate_ranking(
        score_matrix=hybrid_scores
    )

    row = {
        "alpha": alpha,
        "Precision@5": metrics[5]["Precision"],
        "Recall@5": metrics[5]["Recall"],
        "F1@5": metrics[5]["F1"],
        "HR@5": metrics[5]["HitRate"],
        "NDCG@5": metrics[5]["NDCG"],
        "Precision@10": metrics[10]["Precision"],
        "Recall@10": metrics[10]["Recall"],
        "F1@10": metrics[10]["F1"],
        "HR@10": metrics[10]["HitRate"],
        "NDCG@10": metrics[10]["NDCG"],
    }

    alpha_results.append(row)

alpha_results_df = pd.DataFrame(alpha_results)

# Select Best Alpha (Criterion: NDCG@5)
best_row = alpha_results_df.loc[
    alpha_results_df["NDCG@5"].idxmax()
]

best_alpha = best_row["alpha"]

print("\n" + "-" * 60)
print("Optimal Alpha Selection")
print("-" * 60)
print(
    f"Best alpha: {best_alpha:.2f} (Selection criterion: NDCG@5)"
)

# Display Detailed Tuning Results Table
print("\n" + "=" * 60)
print("DISPLAY ALPHA RESULTS")
print("=" * 60)

print("\nHybrid Alpha Tuning Results:")
print("-" * 60)

print(
    alpha_results_df.to_string(
        index=False,
        float_format=lambda x: f"{x:.4f}"
    )
)
print("\n")

# Visualization: Alpha vs Performance Curves 
plt.figure(figsize=(8, 5))

plt.plot(
    alpha_results_df["alpha"],
    alpha_results_df["NDCG@5"],
    marker="o",
    linewidth=2,
    color="#1f77b4",
    label="NDCG@5"
)

plt.plot(
    alpha_results_df["alpha"],
    alpha_results_df["F1@5"],
    marker="s",
    linewidth=2,
    color="#2ca02c",
    label="F1@5"
)

plt.axvline(
    x=best_alpha,
    color="red",
    linestyle="--",
    alpha=0.7,
    label=f"Best Alpha ({best_alpha:.2f})"
)

plt.xlabel("Alpha (CF Weight)", fontsize=11)
plt.ylabel("Metric Score", fontsize=11)
plt.title("Hybrid Tuning: Alpha vs Recommendation Performance", fontsize=12, pad=10)
plt.xticks(ALPHA_VALUES)
plt.legend(loc="best")
plt.grid(True, linestyle=":", alpha=0.6)
plt.tight_layout()
plt.show()

print("\n")

# Sample Tourist Recommendation
print("\n" + "=" * 60)
print("Sample Tourist Recommendation")
print("=" * 60)

# Compute final hybrid score matrix using best alpha
best_hybrid_scores = (
    best_alpha * cf_norm + (1 - best_alpha) * content_norm
)

# Select a representative tourist
user_interaction_counts = train_df.groupby("user_idx").size()

# Select a Tourist with 8-12 Previous Interactions.
eligible_users = user_interaction_counts[
    (user_interaction_counts >= 8) & (user_interaction_counts <= 12)
]

# Randomly Select one Tourist
SAMPLE_USER_IDX = eligible_users.sample(
    1, random_state=RANDOM_SEED
).index[0]

# Convert user_idx Back to original tourist_id
tourist_id = user_ids[SAMPLE_USER_IDX]

print(f"\nTourist ID: {tourist_id}")
print(
    f"Previous interactions: {user_interaction_counts[SAMPLE_USER_IDX]}"
)

# Find previous attractions
previous_items = train_df[
    train_df["user_idx"] == SAMPLE_USER_IDX
].sort_values("rating", ascending=False)

print("\nPrevious Attractions")
print("-" * 70)
print(f"{'Attraction':<45}{'Rating':>10}")
print("-" * 70)

for row in previous_items.itertuples():
    attraction_name = idx_to_item[row.item_idx]
    print(f"{attraction_name:<45}{row.rating:>10.2f}")

# Get attractions already visited
seen_items = set(previous_items["item_idx"])

# Generate candidate attractions
candidate_items = [
    item_idx for item_idx in range(n_items) if item_idx not in seen_items
]

# Compute scores for candidate attractions using best hybrid score matrix
recommendation_scores = []

for item_idx in candidate_items:
    hybrid_score = best_hybrid_scores[SAMPLE_USER_IDX, item_idx]
    recommendation_scores.append((item_idx, hybrid_score))

# Sort attractions by predicted score
recommendation_scores.sort(key=lambda x: x[1], reverse=True)

# Select Top 5 recommendations
top_recommendations = recommendation_scores[:5]

# Display recommendations
print("\nRecommended Attractions")
print("-" * 70)
print(
    f"{'Rank':<8}{'Attraction':<45}{'Hybrid Score':>17}"
)
print("-" * 70)

for rank, (item_idx, hybrid_score) in enumerate(
    top_recommendations, start=1
):
    attraction_name = idx_to_item[item_idx]
    print(
        f"{rank:<8}{attraction_name:<45}{hybrid_score:>17.4f}"
    )

# Create a recommendation DataFrame
recommendation_results = []

for rank, (item_idx, hybrid_score) in enumerate(
    top_recommendations, start=1
):
    recommendation_results.append(
        {
            "Tourist ID": tourist_id,
            "Rank": rank,
            "Attraction": idx_to_item[item_idx],
            "Hybrid Score": round(hybrid_score, 4),
        }
    )

recommendation_results_df = pd.DataFrame(recommendation_results)

# Final Hybrid Tuning Summary
print("\n" + "=" * 60)
print("HYBRID ALPHA TUNING FINAL SUMMARY")
print("=" * 60)
print(f"Best Alpha (CF Weight)    : {best_alpha:.2f}")
print(f"Content Weight (1 - Alpha): {1.0 - best_alpha:.2f}")
print(f"Best Precision@5           : {best_row['Precision@5']:.4f}")
print(f"Best Recall@5              : {best_row['Recall@5']:.4f}")
print(f"Best F1@5                  : {best_row['F1@5']:.4f}")
print(f"Best HR@5                  : {best_row['HR@5']:.4f}")
print(f"Best NDCG@5                : {best_row['NDCG@5']:.4f}")
print(f"Best Precision@10          : {best_row['Precision@10']:.4f}")
print(f"Best Recall@10             : {best_row['Recall@10']:.4f}")
print(f"Best F1@10                 : {best_row['F1@10']:.4f}")
print(f"Best HR@10                 : {best_row['HR@10']:.4f}")
print(f"Best NDCG@10               : {best_row['NDCG@10']:.4f}")
print("=" * 60)
# Out:
# ============================================================
# TUNING HYBRID WEIGHT
# ============================================================
#
# Evaluating hybrid model performance across alpha values...
#
# ------------------------------------------------------------
# Optimal Alpha Selection
# ------------------------------------------------------------
# Best alpha: 0.40 (Selection criterion: NDCG@5)
#
# ============================================================
# DISPLAY ALPHA RESULTS
# ============================================================
#
# Hybrid Alpha Tuning Results:
# ------------------------------------------------------------
#  alpha  Precision@5  Recall@5   F1@5   HR@5  NDCG@5  Precision@10  Recall@10  F1@10  HR@10  NDCG@10
# 0.0000       0.0043    0.0117 0.0062 0.0217  0.0082        0.0045     0.0245 0.0075 0.0448   0.0130
# 0.1000       0.0043    0.0118 0.0062 0.0216  0.0081        0.0046     0.0249 0.0076 0.0454   0.0131
# 0.2000       0.0046    0.0127 0.0066 0.0229  0.0084        0.0047     0.0256 0.0079 0.0468   0.0133
# 0.3000       0.0048    0.0136 0.0069 0.0240  0.0088        0.0048     0.0263 0.0080 0.0476   0.0137
# 0.4000       0.0049    0.0138 0.0071 0.0246  0.0089        0.0047     0.0259 0.0078 0.0470   0.0135
# 0.5000       0.0048    0.0134 0.0069 0.0242  0.0087        0.0046     0.0253 0.0076 0.0456   0.0131
# 0.6000       0.0046    0.0127 0.0066 0.0229  0.0082        0.0044     0.0238 0.0072 0.0432   0.0125
# 0.7000       0.0041    0.0110 0.0058 0.0204  0.0073        0.0043     0.0233 0.0072 0.0428   0.0120
# 0.8000       0.0039    0.0105 0.0056 0.0196  0.0069        0.0042     0.0231 0.0070 0.0422   0.0117
# 0.9000       0.0042    0.0116 0.0060 0.0208  0.0078        0.0042     0.0229 0.0070 0.0417   0.0121
# 1.0000       0.0045    0.0121 0.0064 0.0222  0.0082        0.0046     0.0248 0.0076 0.0449   0.0130
# ============================================================
# Sample Tourist Recommendation
# ============================================================
#
# Tourist ID: 605
# Previous interactions: 8
#
# Previous Attractions
# ----------------------------------------------------------------------
# Attraction                                       Rating
# ----------------------------------------------------------------------
# Ba Da Ling Chang Cheng                             5.00
# Tian Tai Shan                                      5.00
# Tai Shan                                           5.00
# Mo Gan Shan                                        4.80
# Yue Yang Lou                                       4.50
# Shang Hai Ye Sheng Dong Wu Yuan                    4.20
# Shou Xian Gu Cheng                                 4.10
# Mao Shan                                           4.00
#
# Recommended Attractions
# ----------------------------------------------------------------------
# Rank    Attraction                                        Hybrid Score
# ----------------------------------------------------------------------
# 1       Tian Tan Gong Yuan                                      0.8212
# 2       Yi He Yuan                                              0.7972
# 3       Gu Gong Bo Wu Yuan                                      0.7781
# 4       Mu Tian Yu Chang Cheng                                  0.7770
# 5       Gong Wang Fu                                            0.7542
#
# ============================================================
# HYBRID ALPHA TUNING FINAL SUMMARY
# ============================================================
# Best Alpha (CF Weight)    : 0.40
# Content Weight (1 - Alpha): 0.60
# Best Precision@5           : 0.0049
# Best Recall@5              : 0.0138
# Best F1@5                  : 0.0071
# Best HR@5                  : 0.0246
# Best NDCG@5                : 0.0089
# Best Precision@10          : 0.0047
# Best Recall@10             : 0.0259
# Best F1@10                 : 0.0078
# Best HR@10                 : 0.0470
# Best NDCG@10               : 0.0135
# ============================================================

# %% [markdown]
# ## Baseline Model

# %%
# POPULARITY BASELINE
print("\n" + "=" * 60)
print("POPULARITY BASELINE")
print("=" * 60)

# Average rating for each attraction
item_mean_rating = (
    train_df
    .groupby("item_idx")["rating"]
    .mean()
)
 
# Number of ratings for each attraction
item_rating_count = (
    train_df
    .groupby("item_idx")["rating"]
    .count()
)
 
# Popularity score
popularity_score = (
    item_mean_rating
    * np.log1p(item_rating_count)
)
 
popularity_vector = np.full(
    n_items,
    popularity_score.mean()
)
 
for item_idx, score in (
    popularity_score.items()
):
 
    popularity_vector[item_idx] = score
 
# Normalize popularity score
popularity_norm_vector = (
    popularity_vector
    - popularity_vector.min()
)

max_popularity = (
    popularity_norm_vector.max()
)
 
if max_popularity != 0:
 
    popularity_norm_vector /= (
        max_popularity
    )
 
print("Popularity baseline ready")
# Out:
# ============================================================
# POPULARITY BASELINE
# ============================================================
# Popularity baseline ready

# %% [markdown]
# ## Model Evaluation Performance

# %%
print("\n" + "=" * 60)
print("RATING PREDICTION & CLASSIFICATION METRICS")
print("=" * 60)

LIKE_THRESHOLD = 4
y_true_binary = (y_true >= LIKE_THRESHOLD).astype(int)

# Dictionaries to store results for visualization
model_metrics = []
confusion_matrices = {}
prediction_scores = {}

# Test data
test_users = test_df["user_idx"].values
test_items = test_df["item_idx"].values
y_true = test_df["rating"].values

# Binary ground truth
# Rating >= 4 = Liked
# Rating < 4  = Not liked
y_true_binary = (y_true >= LIKE_THRESHOLD).astype(int)

# Predictions
svd_preds = pred_cf_matrix[test_users, test_items]
content_preds = pred_content_matrix[test_users, test_items]
nn_preds = pred_nn_matrix[test_users, test_items]
hybrid_pred_matrix = (
    best_alpha * pred_cf_matrix
    + (1 - best_alpha) * pred_content_matrix
)

hybrid_preds = hybrid_pred_matrix[test_users, test_items]

# RATING MODEL EVALUATION FUNCTION
def evaluate_rating_model(name, continuous_preds):
    # Continuous Metrics
    rmse = np.sqrt(mean_squared_error(y_true, continuous_preds))
    mae = mean_absolute_error(y_true, continuous_preds)
    
    # Binary Classification Metrics
    binary_preds = (continuous_preds >= LIKE_THRESHOLD).astype(int)
    acc = np.mean(y_true_binary == binary_preds)
    
    # Confusion matrix components
    cm = confusion_matrix(y_true_binary, binary_preds)
    
    # Handle cases where confusion matrix might be 1x1 if predictions are all one class
    if cm.shape == (2, 2):
        tn, fp, fn, tp = cm.ravel()
    else:
        tn = fp = fn = tp = 0 # Fallback 
        
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1 = (2 * precision * recall / (precision + recall)) if (precision + recall) > 0 else 0
    
    # Print results
    print(f"{name}:")
    print(f"    RMSE = {rmse:.4f} | MAE = {mae:.4f}")
    print(f"    Class Accuracy = {acc:.4f} | Class F1-Score = {f1:.4f}\n")
    
    # Save results for plotting
    model_metrics.append({
        'Model': name,
        'RMSE': rmse,
        'MAE': mae,
        'Accuracy': acc,
        'F1-Score': f1
    })
    confusion_matrices[name] = cm
    prediction_scores[name] = continuous_preds

# Evaluate all models
evaluate_rating_model("SVD Collaborative", svd_preds)
evaluate_rating_model("TF-IDF Content", content_preds)
evaluate_rating_model("Neural Network", nn_preds)
evaluate_rating_model(f"Hybrid", hybrid_preds)

# Convert metrics to a DataFrame for easy plotting
metrics_df = pd.DataFrame(model_metrics).set_index('Model')

# VISUALIZATIONS 
sns.set_theme(style="whitegrid")
fig = plt.figure(figsize=(15, 20))

# Plot A & B: Bar Charts for Metrics
# Create subplots for the bar charts at the top
ax1 = plt.subplot2grid((3, 2), (0, 0))
ax2 = plt.subplot2grid((3, 2), (0, 1))

# Error Metrics (Lower is better)
metrics_df[['RMSE', 'MAE']].plot(kind='bar', ax=ax1, colormap='Reds_r', edgecolor='black')
ax1.set_title('A. Prediction Error (Lower is Better)', fontsize=14, fontweight='bold')
ax1.set_ylabel('Error Score', fontsize=12)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15, ha='right')
ax1.legend(loc='lower right')
ax1.margins(y=0.15) 
for container in ax1.containers:
    ax1.bar_label(container, fmt='%.4f', padding=3, fontsize=10)

# Classification Metrics (Higher is better)
metrics_df[['Accuracy', 'F1-Score']].plot(kind='bar', ax=ax2, colormap='Greens_r', edgecolor='black')
ax2.set_title('B. Classification Performance (Higher is Better)', fontsize=14, fontweight='bold')
ax2.set_ylabel('Score', fontsize=12)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=15, ha='right')
ax2.legend(loc='lower right')
ax2.set_ylim(0, 1.15) 
for container in ax2.containers:
    ax2.bar_label(container, fmt='%.4f', padding=3, fontsize=10)
# Out:
# ============================================================
# RATING PREDICTION & CLASSIFICATION METRICS
# ============================================================
# SVD Collaborative:
#     RMSE = 0.2872 | MAE = 0.2449
#     Class Accuracy = 0.8955 | Class F1-Score = 0.9436
#
# TF-IDF Content:
#     RMSE = 0.3939 | MAE = 0.3212
#     Class Accuracy = 0.8895 | Class F1-Score = 0.9415
#
# Neural Network:
#     RMSE = 0.3090 | MAE = 0.2587
#     Class Accuracy = 0.8895 | Class F1-Score = 0.9400
#
# Hybrid:
#     RMSE = 0.3312 | MAE = 0.2751
#     Class Accuracy = 0.8963 | Class F1-Score = 0.9452

# %%
# Final Model Comparison
print("\n" + "=" * 60)
print("FINAL MODEL COMPARISON")
print("=" * 60)
 
# SVD
svd_metrics = evaluate_ranking(
    score_matrix=cf_norm
)

# TF-IDF Content-Based
content_metrics = evaluate_ranking(
    score_matrix=content_norm
)

# Neural Network
nn_metrics = evaluate_ranking(
    score_matrix=nn_norm
)
 
# Hybrid
hybrid_final_scores = (
    best_alpha * cf_norm + (1 - best_alpha) * content_norm
)
 
hybrid_metrics = evaluate_ranking(
    score_matrix=hybrid_final_scores
)
 
# Popularity
popularity_metrics = evaluate_ranking(
    score_vector=popularity_norm_vector
)
 
# Create comparison table
comparison_rows = []
 
for name, metrics in [
    ("Popularity",popularity_metrics),
    ("SVD Collaborative Filtering",svd_metrics),
    ("TF-IDF Content-Based",content_metrics),
    ("Neural Network (MLP + embeddings)",nn_metrics),
    (f"Hybrid (alpha={best_alpha:.2f})",hybrid_metrics)
]:
    comparison_rows.append({
        "Model": name,
        "Prec@5":
            metrics[5]["Precision"],
        "Rec@5":
            metrics[5]["Recall"],
        "F1@5":
            metrics[5]["F1"],
        "HR@5":
            metrics[5]["HitRate"],
        "NDCG@5":
            metrics[5]["NDCG"],
    })
comparison_df = pd.DataFrame(
    comparison_rows
)
print(
    comparison_df.to_string(
        index=False,
        float_format=lambda x:
            f"{x:.4f}"
    )
)
# Out:
# ============================================================
# FINAL MODEL COMPARISON
# ============================================================
#                             Model  Prec@5  Rec@5   F1@5   HR@5  NDCG@5
#                        Popularity  0.0038 0.0105 0.0055 0.0192  0.0078
#       SVD Collaborative Filtering  0.0045 0.0121 0.0064 0.0222  0.0082
#              TF-IDF Content-Based  0.0043 0.0117 0.0062 0.0217  0.0082
# Neural Network (MLP + embeddings)  0.0053 0.0139 0.0075 0.0261  0.0097
#               Hybrid (alpha=0.40)  0.0049 0.0138 0.0071 0.0246  0.0089

# %%
# VISUALIZATIONS: RANKING METRICS DASHBOARD
# Set the dataframe index to Model for easy plotting
metrics_to_plot = comparison_df.set_index('Model')

sns.set_theme(style="whitegrid")
fig = plt.figure(figsize=(16, 12))

# Plot A: Precision & Recall @5 
ax1 = plt.subplot2grid((2, 2), (0, 0))
metrics_to_plot[['Prec@5', 'Rec@5']].plot(kind='barh', ax=ax1, colormap='Blues_r', edgecolor='black')
ax1.set_title('A. Precision & Recall @ 5', fontsize=14, fontweight='bold')
ax1.set_xlabel('Score', fontsize=12)
ax1.set_ylabel('') 
ax1.invert_yaxis() 
ax1.legend(loc='lower right')
ax1.set_xlim(left=0)
ax1.margins(x=0.15) # Adds extra space on the right so labels aren't cut off
for container in ax1.containers:
    ax1.bar_label(container, fmt='%.4f', padding=3, fontsize=10)

# Plot B: F1-Score @5
ax2 = plt.subplot2grid((2, 2), (0, 1))
metrics_to_plot[['F1@5']].plot(kind='barh', ax=ax2, color='mediumseagreen', edgecolor='black', legend=False)
ax2.set_title('B. F1-Score @5', fontsize=14, fontweight='bold')
ax2.set_xlabel('Score', fontsize=12)
ax2.set_ylabel('')
ax2.invert_yaxis()
ax2.set_xlim(left=0)
ax2.margins(x=0.15)
for container in ax2.containers:
    ax2.bar_label(container, fmt='%.4f', padding=3, fontsize=10)

# Plot C: Hit Rate (HR) @5 
ax3 = plt.subplot2grid((2, 2), (1, 0))
metrics_to_plot[['HR@5']].plot(kind='barh', ax=ax3, color='coral', edgecolor='black', legend=False)
ax3.set_title('C. Hit Rate @5 (Users with ≥1 relevant item)', fontsize=14, fontweight='bold')
ax3.set_xlabel('Score', fontsize=12)
ax3.set_ylabel('')
ax3.invert_yaxis()
ax3.set_xlim(left=0)
ax3.margins(x=0.15)
for container in ax3.containers:
    ax3.bar_label(container, fmt='%.4f', padding=3, fontsize=10)

# Plot D: NDCG @5 
ax4 = plt.subplot2grid((2, 2), (1, 1))
metrics_to_plot[['NDCG@5']].plot(kind='barh', ax=ax4, color='mediumpurple', edgecolor='black', legend=False)
ax4.set_title('D. NDCG @5 (Ranking Quality)', fontsize=14, fontweight='bold')
ax4.set_xlabel('Score', fontsize=12)
ax4.set_ylabel('')
ax4.invert_yaxis()
ax4.set_xlim(left=0)
ax4.margins(x=0.15)
for container in ax4.containers:
    ax4.bar_label(container, fmt='%.4f', padding=3, fontsize=10)

plt.suptitle('Final Model Ranking Evaluation (Top-5 Recommendations)', fontsize=18, fontweight='bold', y=0.98)
plt.tight_layout(pad=3.0)
plt.show()

# %%
import pickle
import joblib

# Save the pre‑computed score matrices
np.save('pred_cf_matrix.npz', pred_cf_matrix)
np.save('pred_content_matrix.npz', pred_content_matrix)
np.save('pred_nn_matrix.npy', pred_nn_matrix)

# Save the hybrid matrix 
best_alpha = 0.4  # or your best value
hybrid_matrix = best_alpha * pred_cf_matrix + (1 - best_alpha) * pred_content_matrix
np.save('hybrid_matrix.npy', hybrid_matrix.astype(np.float32))

# Save the trained models 
# For SVD (Surprise)
import pickle
with open('svd_model.pkl', 'wb') as f:
    pickle.dump(svd_model, f)

# For MLP
import joblib
joblib.dump(mlp_model, 'mlp_model.pkl')
joblib.dump(nn_scaler, 'nn_scaler.pkl')

# For TF‑IDF vectorizer and SVD reducer
import joblib
joblib.dump(vectorizer, 'tfidf_vectorizer.pkl')
joblib.dump(content_svd, 'content_svd.pkl')   # TruncatedSVD used to reduce TF‑IDF

# Save the mapping dictionaries and other metadata
with open('user_ids.pkl', 'wb') as f:
    pickle.dump(user_ids, f)
with open('item_ids.pkl', 'wb') as f:
    pickle.dump(item_ids, f)
with open('idx_to_item.pkl', 'wb') as f:
    pickle.dump(idx_to_item, f)
with open('user_to_idx.pkl', 'wb') as f:
    pickle.dump(user_to_idx, f)
with open('item_to_idx.pkl', 'wb') as f:
    pickle.dump(item_to_idx, f)

# Save the attraction metadata 
attr_meta.to_csv('attraction_metadata.csv', index=False)

# Save training user–item sets for excluding seen items
train_seen = train_df.groupby('user_idx')['item_idx'].apply(set).to_dict()
with open('train_seen.pkl', 'wb') as f:
    pickle.dump(train_seen, f)

print("All artifacts saved successfully.")
# Out:
# All artifacts saved successfully.
